# %% [markdown]
# # Lab 1 — Supervised Fine-Tuning: contract review that cites its evidence
#
# ## Notebook 1 — The task, and preparing the data
#
# ### The task in one sentence
#
# Given a non-disclosure agreement, answer a **fixed 17-point legal checklist** about
# it, and for each answer **cite the clause numbers** that justify it.
#
# ### The input
#
# One request contains the instruction, the contract split into numbered spans, and
# the checklist — in that order. This is the real prompt template, with the contract
# truncated and the checklist showing 3 of its 17 items:
#
# ```
# You are a contract review assistant. You review a non-disclosure agreement (NDA)
# against a fixed checklist of 17 legal hypotheses.
#
# For EACH hypothesis, decide:
# - "Entailment": the contract states or implies the hypothesis is true.
# - "Contradiction": the contract states something that conflicts with the hypothesis.
# - "NotMentioned": the contract does not address it.
#
# Also cite the span numbers that justify the decision (the exact spans a lawyer
# would point to). Cite spans only for Entailment or Contradiction; use an empty
# list for NotMentioned. Read exceptions and carve-outs carefully: a clause with an
# exception may contradict a hypothesis stated absolutely.
#
# CONTRACT (numbered spans):
# [0] NAVIDEC, INCORPORATED
# [1] TRADE SECRET/NON-DISCLOSURE AGREEMENT
# [2] In consideration of the mutual promises made herein, as well as the agreement
#     between Navidec, Incorporated and _______ , the parties hereby agree as follows:
# [3] _______ , agrees that, in consideration for being shown or told about certain
#     trade secrets or property belonging to Navidec, Incorporated, _______ , shall
#     not disclose or cause to be disclosed, disseminated or distributed any
#     information concerning said trade secret or property to any person, entity,
#     business or other individual or company without the prior written permission
#     of Navidec, Incorporated.
# [4] Further, _______ , agrees not to use, either directly or indirectly any of the
#     material, ideas, objects or portions thereof of said trade secret or property
#     disclosed by Navidec, Incorporated in any manner whatsoever without the prior
#     written consent of Navidec, Incorporated.
# [5] Any dispute that arises hereunder shall be resolved by arbitration pursuant to
#     the rules of the American Arbitration Association or the rules of the State of
#     Colorado.
#     ... (remaining spans)
#
# CHECKLIST:
# nda-2: Confidential Information shall only include technical information.
#        (None-inclusion of non-technical information)
# nda-7: Receiving Party may share some Confidential Information with some
#        third-parties (including consultants, agents and professional advisors).
#        (Sharing with third-parties)
# nda-5: Receiving Party may share some Confidential Information with some of
#        Receiving Party's employees. (Sharing with employees)
#     ... (17 items total, always in the same order)
#
# Respond with JSON only, no other text:
# {"nda-1": {"label": "Entailment|Contradiction|NotMentioned", "evidence": [span numbers]}, ...}
# Include an entry for every hypothesis key listed above.
# ```
#
# Note the last line of the instruction: **carve-outs matter**. That single sentence
# is what the example below turns on.
#
# Prompt length: median ~2,700 tokens, mean ~2,900, and the longest contract in the
# training set reaches ~12,400. The whole contract goes in every time, because any
# of the 17 items could be decided by any clause.
#
# ### The expected output
#
# Strict JSON. One key per checklist item, in the checklist's order, each with a
# verdict and a list of span numbers. This is the complete, exact answer for the
# contract above — all 17 items, nothing omitted:
#
# ```json
# {"nda-11": {"label": "NotMentioned",  "evidence": []},
#  "nda-16": {"label": "NotMentioned",  "evidence": []},
#  "nda-15": {"label": "NotMentioned",  "evidence": []},
#  "nda-10": {"label": "NotMentioned",  "evidence": []},
#  "nda-2":  {"label": "Contradiction", "evidence": [3, 4]},
#  "nda-1":  {"label": "NotMentioned",  "evidence": []},
#  "nda-19": {"label": "NotMentioned",  "evidence": []},
#  "nda-12": {"label": "NotMentioned",  "evidence": []},
#  "nda-20": {"label": "NotMentioned",  "evidence": []},
#  "nda-3":  {"label": "NotMentioned",  "evidence": []},
#  "nda-18": {"label": "NotMentioned",  "evidence": []},
#  "nda-7":  {"label": "Contradiction", "evidence": [3]},
#  "nda-17": {"label": "NotMentioned",  "evidence": []},
#  "nda-8":  {"label": "NotMentioned",  "evidence": []},
#  "nda-13": {"label": "NotMentioned",  "evidence": []},
#  "nda-5":  {"label": "Contradiction", "evidence": [3]},
#  "nda-4":  {"label": "Entailment",    "evidence": [4]}}
# ```
#
# ### Why those are the right answers
#
# Take `nda-5`: *"Receiving Party may share some Confidential Information with some
# of Receiving Party's employees."*
#
# Span [3] forbids disclosure **"to any person, entity, business or other individual
# or company"** with no exception for employees. Most NDAs carve one out; this one
# does not. So the checklist statement is not merely unaddressed — it is
# **contradicted**, and span [3] is the proof.
#
# `nda-7` (sharing with third parties) is contradicted by the same span. `nda-2`
# (*"Confidential Information shall only include technical information"*) is
# contradicted by [3] and [4] together, which cover "material, ideas, objects" and
# "trade secrets or property" far beyond technical information. And `nda-4`
# (*"shall not use Confidential Information for any purpose other than the purposes
# stated in the Agreement"*) is **entailed** by [4].
#
# Two things to notice, because they define the difficulty:
#
# - **One clause drives several answers.** Span [3] decides three items. This is not
#   retrieval where each question has its own passage.
# - **13 of 17 items are `NotMentioned`.** Short NDAs are silent on most of the
#   checklist. That skew is why accuracy alone is a weak metric here, and why the
#   evaluation in notebook 3 leads with evidence-F1.
#
# ### Why the citations are the point
#
# A verdict alone is unusable. "Item 5 fails" gives a reviewer nothing to act on;
# "Item 5 fails, see clause 3" is verifiable in seconds. The citation is what turns
# model output into reviewable work, and it is also the part that cannot be faked —
# guessing the most common verdict gets you 66% accuracy but scores **exactly zero**
# on evidence.
#
# ### The same pattern shows up far beyond legal work
#
# The shape of this task, not its subject, is what makes it worth studying: **a fixed
# checklist, applied repeatedly to documents of one type, where the output is a
# verdict plus a pointer to the text that justifies it.** Swap the checklist and the
# document and you have:
#
# - **Vendor security review** — does this vendor's policy documentation satisfy each
#   control in our questionnaire, and which paragraph says so?
# - **Insurance claims adjudication** — does this claim meet each condition of the
#   policy, citing the relevant clause?
# - **Regulatory filing checks** — does this prospectus disclose each required item?
# - **Clinical trial screening** — does this patient record satisfy each eligibility
#   criterion, citing the note that shows it?
# - **Procurement and RFP compliance** — does this bid meet every mandatory
#   requirement?
# - **Change management** — does this change request comply with each internal policy
#   rule?
#
# All of them share the two failure modes that matter here: claiming a requirement is
# satisfied when the document is actually silent, and pointing at the wrong evidence.
# This lab is about measuring and fixing exactly those.
#
# ### Why not just call a frontier model? — the measurements
#
# The right first question. Here is the whole result of this lab, up front. Every row
# is the **same 123 held-out contracts, 2,091 decisions**, zero-shot, scored by the
# same code:
#
# | Model | Accuracy | Macro-F1 | Evidence-F1 | Contradiction-F1 |
# |---|---|---|---|---|
# | Qwen3-4B base | 68.0 | 60.5 | 40.4 | 44.0 |
# | Claude Sonnet 4.6 | 81.8 | 77.1 | 70.2 | 63.1 |
# | **Qwen3-4B fine-tuned** | **88.1** | **83.9** | **76.1** | **71.3** |
#
# Three things to take from this.
#
# **Sonnet is decent but not done.** 81.8% accuracy and 70.2 evidence-F1 is a usable
# assistant, not an autonomous reviewer — it still misreads about one checklist item in
# six.
#
# **The small model out of the box is weak.** 68.0% accuracy sounds tolerable until you
# note that several checklist items are 77–86% skewed to one answer, so much of that
# comes from the label distribution rather than from reading the contract. Its
# evidence-F1 of 40.4 is the telling number: it frequently cites the wrong clause even
# when the verdict happens to be right.
#
# **Prompting the frontier model harder does not fix it either.** Across the Sonnet
# configurations tried — few-shot prompting, one item per call, step-by-step reasoning —
# none moved it more than a point or two. That is the realistic ceiling for a prompted
# frontier model on this task.
#
# **Fine-tuning a 4B model passes it.** 88.1% accuracy and 76.1 evidence-F1, from a
# model roughly two orders of magnitude smaller, trained in 10-20 minutes for under
# $2. It is better precisely where it matters: contradiction-F1 71.3 against Sonnet's
# 63.1, meaning it is far better at spotting the clause that *conflicts* with your
# requirement rather than merely being absent.
#
# That last point is the reason this lab exists. Notebooks 2 and 3 are where you
# reproduce it.
#
# ### And it is cheaper to run
#
# Quality is only half the argument. The same measured reference run, at standard
# Sonnet pricing ($3/$15 per 1M tokens):
#
# | | Per contract | 2,000/month | 20,000/month |
# |---|---|---|---|
# | Claude Sonnet 4.6 | $0.01696 | $34 | $339 |
# | Fine-tuned Qwen3-4B, Bedrock Custom Model Import | **$0.00353** | **$7** | **$71** |
#
# Roughly **5x cheaper per contract**, mostly because a 4B model is small. Creating
# the model costs **under $2 and 10-20 minutes** for the LoRA job you will run in
# notebook 2.
#
# So on this task you get both lower cost and higher accuracy, which is unusual enough
# to be worth measuring rather than assuming. Serving-cost modelling is out of scope
# for this lab; use the [AWS Pricing Calculator](https://calculator.aws/) with the
# token counts above.
#
# ### Few-shot prompting does not rescue the small model
#
# The obvious cheap fix is to put worked examples in the prompt. On this task it does
# not work, and understanding why is the argument for fine-tuning.
#
# Even for a frontier model, demonstrations stop helping quickly: a few shots buy about
# a point of accuracy and more shots give it back. For a 4B model the effect is not
# merely absent, it is actively harmful. Measured on a 4B base at 0/3/5 shots:
#
# | Condition | Predicted `Contradiction` (gold: 81) | Mean spans cited (gold: 2.01) | Evidence precision |
# |---|---|---|---|
# | 0-shot | 36 | 1.09 | **82.8** |
# | 3-shot | 14 | 1.20 | 61.0 |
# | 5-shot | **9** | **2.13** | **40.2** |
#
# Read the last two columns together. Zero-shot the model cites too few clauses but is
# usually right about them. Shown examples whose answers average 2.00 spans, it starts
# citing 2.13 — near-perfect imitation of the *format* — while precision halves. It
# learned **how many** clauses a good answer cites without gaining any ability to pick
# **which**. At the same time it drifts to the demonstrations' dominant label and stops
# predicting the rare class almost entirely: 36 contradictions predicted at 0-shot, 9 at
# 5-shot, against 81 in the gold.
#
# The obvious alternative explanations were checked and do not hold: citations stay
# inside the correct document (0.9% out-of-range span IDs at 5-shot), and the damage is
# flat across contract-length quartiles, so it is not long-context dilution.
#
# > Provenance: this 0/3/5-shot sweep was run on Qwen3.5-4B, a sibling 4B base model,
# > because it was the sweep already available end to end. Qwen3.5-4B is the *stronger*
# > of the two 4B bases (76.7% zero-shot accuracy versus Qwen3-4B's 68.0%), so
# > demonstrations degrading it is the conservative version of the claim.
#
# **The conclusion.** Demonstrations teach form, and form is not the bottleneck — the
# base model already emits valid JSON zero-shot with zero parse failures. What it lacks
# is the judgement to separate *"the contract is silent on this"* from *"the contract
# addresses this"* from *"the contract forbids this."* A handful of examples cannot
# install that; they only supply a template to imitate, which displaces whatever weak
# discrimination the model had.
#
# Fine-tuning on 423 contracts — 7,191 labelled judgements — does install it.
#
# ### The data
#
# [ContractNLI](https://stanfordnlp.github.io/contract-nli/) (Koreeda & Manning,
# *Findings of EMNLP 2021*), released under **CC-BY-4.0**. 607 real NDAs from EDGAR
# filings and the public web, annotated against this fixed 17-point checklist.
#
# For every (contract, checklist item) pair the annotation gives:
#
# | Field | Meaning |
# |---|---|
# | `choice` | `Entailment` / `Contradiction` / `NotMentioned` |
# | `spans` | the span numbers a lawyer would point to as justification |
#
# Splits are **document-level** and stratified by source format, so no contract
# appears in two splits: 423 train / 61 dev / 123 test.

# %% [markdown]
# ### Install requirements

# %%
# %pip install -r requirements.txt

# %% [markdown]
# #### Setup and dependencies

# %%
import boto3
from sagemaker.core.helper.session_helper import Session, get_execution_role

sess = Session()
sagemaker_session_bucket = None
if sagemaker_session_bucket is None and sess is not None:
    sagemaker_session_bucket = sess.default_bucket()

try:
    role = get_execution_role()
except ValueError:
    iam = boto3.client("iam")
    role = iam.get_role(RoleName="sagemaker_execution_role")["Role"]["Arn"]

s3_client = boto3.client("s3")
sess = Session(default_bucket=sagemaker_session_bucket)
sm_client = boto3.client("sagemaker", region_name=sess.boto_region_name)
bucket_name = sess.default_bucket()
default_prefix = sess.default_bucket_prefix

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {bucket_name}")
print(f"sagemaker session region: {sess.boto_region_name}")

# %% [markdown]
# ### Download the dataset
#
# `ensure_dataset()` fetches the CC-BY-4.0 archive from Stanford and unpacks it
# into `./data`. Nothing else in the lab needs network access to the dataset.

# %%
import contractnli as C

C.ensure_dataset("./data")

train_docs, labels = C.load("train")
dev_docs, _ = C.load("dev")
test_docs, _ = C.load("test")

print(f"train {len(train_docs)} contracts | dev {len(dev_docs)} | test {len(test_docs)}")
print(f"checklist items: {len(labels)}")

# %% [markdown]
# ### The checklist the model has to answer

# %%
for k, v in sorted(labels.items(), key=lambda kv: int(kv[0].split("-")[1])):
    print(f"{k:7s} [{v['short_description']}]")
    print(f"        {v['hypothesis']}")

# %% [markdown]
# ### Look at one real contract
#
# Below is one of the shortest NDAs in the test set, split into the numbered spans
# the model will see, followed by the gold answer. Read span [3] and then look at
# the labels for `nda-5` (sharing with employees) and `nda-7` (sharing with
# third-parties).

# %%
doc = sorted(test_docs, key=lambda d: len(d["text"]))[1]
spans = C.doc_spans(doc)

print(f"{doc['file_name']}  —  {len(doc['text'].split())} words, {len(spans)} spans\n")
for i, t in spans:
    print(f"[{i}] {t[:160]}")

# %%
gold = C.gold_for(doc)
print("gold answer:\n")
for k in sorted(gold, key=lambda x: int(x.split("-")[1])):
    v = gold[k]
    ev = f"  evidence={v['spans']}" if v["spans"] else ""
    print(f"{k:7s} {v['choice']:14s}{ev}   [{labels[k]['short_description']}]")

# %% [markdown]
# ### Check the answer against the clause you just read
#
# This is the contract from the introduction, and span [3] is that blanket
# prohibition. Notice it drives three separate `Contradiction` verdicts:
#
# | Item | Subject | Evidence |
# |---|---|---|
# | `nda-5` | sharing with employees | `[3]` |
# | `nda-7` | sharing with third parties | `[3]` |
# | `nda-2` | only technical information is confidential | `[3, 4]` |
#
# One clause, three verdicts — which is why the model has to reason over the whole
# document per item rather than retrieve one passage per question.
#
# Notice also that 13 of the 17 items are `NotMentioned`. Short NDAs are silent on most
# of the checklist, and that skew is why accuracy alone is a weak metric here — see
# notebook 3.

# %% [markdown]
# ### The prompt
#
# This is the single most important design decision in the lab, so read it rather than
# skim it. Everything the model will ever see is this template with three slots filled
# in: the number of checklist items, the contract as numbered spans, and the checklist
# itself.
#
# It is defined **once**, in `contractnli.py`, and used by every notebook — data prep
# here, the frontier baseline in notebook 3, and the serving checks in 4 and 4a. That
# is deliberate: the promise that *the training prompt is byte-identical to the
# inference prompt* only holds if there is exactly one copy. A second copy pasted into
# a notebook is how train/serve skew gets introduced.
#
# Print it, change it, experiment — but change it in one place.

# %%
# The exact template. {n}, {spans} and {checklist} are the only substitutions.
print(C.INSTRUCTION)

# %% [markdown]
# To experiment with the wording, set `C.INSTRUCTION` here and re-run the record
# build below — every notebook then picks up your version:
#
# ```python
# C.INSTRUCTION = """...your wording, keeping {n}, {spans} and {checklist}..."""
# ```
#
# The assertion in the next cell is what protects the byte-identical promise: the
# prompt stored in each training record must be exactly what `build_prompt` produces
# at inference time.

# %% [markdown]
# ### Build the training records
#
# One training record = one contract, with all 17 verdicts in the completion. So
# 423 records — but each carries 17 supervised decisions plus the evidence spans,
# which is roughly 7,200 labelled judgements.
#
# Two deliberate choices:
#
# - **The prompt at training time is byte-identical to the prompt at inference
#   time.** No train/serve skew.
# - **We keep the dataset's own document-level splits.** A random row-level split
#   would put spans from the same contract in both train and test, and the
#   reported numbers would be meaningless.
#
# The alternative — one record per (contract, checklist item), 7,191 short records
# — gives better gradient diversity but re-encodes the whole contract 17 times, so
# roughly 17x the training and evaluation compute. Not worth it here.

# %%
import json

label_keys = list(labels.keys())


def make_records(docs, test_format=False):
    rows = []
    for d in docs:
        g = C.gold_for(d)
        completion = json.dumps(
            {k: {"label": g[k]["choice"], "evidence": list(g[k]["spans"])}
             for k in label_keys if k in g}
        )
        prompt = C.build_prompt(d, labels)
        rows.append({"query": prompt, "response": completion} if test_format
                    else {"prompt": prompt, "completion": completion})
    return rows


records = {"train": make_records(train_docs),
           "val": make_records(dev_docs),
           "test": make_records(test_docs, test_format=True)}

for name, rows in records.items():
    key = "prompt" if name != "test" else "query"
    avg = sum(len(r[key]) for r in rows) // len(rows)
    print(f"{name:5s}: {len(rows):4d} records, avg prompt {avg:6d} chars (~{avg // 4} tokens)")

# The byte-identical promise, enforced rather than asserted in prose: every stored
# training prompt must equal what build_prompt() produces at inference time.
for split, docs in (("train", train_docs), ("val", dev_docs)):
    for rec, doc in zip(records[split], docs):
        assert rec["prompt"] == C.build_prompt(doc, labels), (
            f"prompt drift in {split}: stored record differs from build_prompt()")
print("verified: stored prompts are byte-identical to build_prompt() output")

# %% [markdown]
# Inspect one complete training record — this is exactly what the model sees and what it must produce.

# %%
sample = min(records["train"], key=lambda r: len(r["prompt"]))
print(sample["prompt"])
print("\n" + "=" * 70 + "\nCOMPLETION\n" + "=" * 70)
print(json.dumps(json.loads(sample["completion"]), indent=1)[:800], "...")

# %% [markdown]
# #### Write to disk and upload to Amazon S3

# %%
import pathlib
import shutil

from config import DATASET_PREFIX

local = pathlib.Path("./sft_data")
if local.exists():
    shutil.rmtree(local)

for name, rows in records.items():
    d = local / name
    d.mkdir(parents=True, exist_ok=True)
    with open(d / "dataset.jsonl", "w") as f:
        for r in rows:
            f.write(json.dumps(r) + "\n")

input_path = (f"{default_prefix}/datasets/{DATASET_PREFIX}" if default_prefix
              else f"datasets/{DATASET_PREFIX}")

s3_paths = {}
for name in records:
    key = f"{input_path}/{name}/dataset.jsonl"
    s3_client.upload_file(str(local / name / "dataset.jsonl"), bucket_name, key)
    s3_paths[name] = f"s3://{bucket_name}/{key}"
    print(s3_paths[name])

# %% [markdown]
# #### Register the datasets
#
# `DataSet.create` registers the S3 objects with the SageMaker AI registry so the
# serverless trainer can consume them by name.
#
# > **Gotcha worth knowing:** if you later overwrite the S3 object in place, the
# > registration still looks valid because the name and path have not changed. You
# > must delete and re-register the dataset for corrected data to take effect.

# %%
from sagemaker.ai_registry.dataset import DataSet
from sagemaker.ai_registry.dataset_utils import CustomizationTechnique


def register(name, source, technique=None, force=False):
    try:
        ds = DataSet.get(name=name)
        if not force and getattr(ds, "source", None) == source:
            print(f"dataset already registered: {name}")
            return ds
        print(f"re-registering {name}")
        DataSet.delete_by_name(name)
    except Exception:
        pass
    kwargs = dict(name=name, source=source, wait=True)
    if technique is not None:
        kwargs["customization_technique"] = technique
    ds = DataSet.create(**kwargs)
    print(f"created dataset: {name}")
    return ds


training_dataset = register(f"{DATASET_PREFIX}-train", s3_paths["train"],
                            CustomizationTechnique.SFT)
val_dataset = register(f"{DATASET_PREFIX}-val", s3_paths["val"],
                        CustomizationTechnique.SFT)
test_dataset = register(f"{DATASET_PREFIX}-test", s3_paths["test"])

# %% [markdown]
# ### What you built
#
# 423 training records, 61 validation, 123 held-out test, registered and ready.
#
# Continue to **notebook 2** to run the serverless LoRA fine-tuning job.
