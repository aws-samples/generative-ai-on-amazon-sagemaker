# %% [markdown]
# # Monitoring Large Language Models (LLMs) with WhyLabs LangKit
#
# LangKit is an open-source text metrics toolkit for monitoring language models. It offers an array of methods for extracting relevant signals from the input and/or output text, which are compatible with the open-source data logging library whylogs.
#
# In this example we'll show how to generate out-of-the-box metrics for monitoring LLMs using LangKit and visualize them in the WhyLabs Observability Platform.
#
# LangKit can extract relevant signals from unstructured text data, such as:
#
# - Text Quality
# - Text Relevance
# - Security and Privacy
# - Sentiment and Toxicity

# %% [markdown]
# ### Install Dependencies

# %%
# Install the fmeval package
# !pip install -U datasets==2.21.0
# !pip install -U jsonlines==4.0.0
# !pip install -U fmeval==1.2.0
# !pip install -U py7zr==0.22.0
# %pip install 'langkit[all]'
# Out:
# Requirement already satisfied: datasets==2.21.0 in /opt/conda/lib/python3.10/site-packages (2.21.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (15.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets==2.21.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (0.24.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets==2.21.0) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets==2.21.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets==2.21.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets==2.21.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets==2.21.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets==2.21.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets==2.21.0) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets==2.21.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets==2.21.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets==2.21.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets==2.21.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets==2.21.0) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets==2.21.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets==2.21.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets==2.21.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.21.0) (1.16.0)
# Requirement already satisfied: jsonlines==4.0.0 in /opt/conda/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonlines==4.0.0) (23.2.0)
# Requirement already satisfied: fmeval==1.2.0 in /opt/conda/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: IPython in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (8.25.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (3.9.5)
# Requirement already satisfied: bert-score<0.4.0,>=0.3.13 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (0.3.13)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.60.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (1.66.1)
# Requirement already satisfied: ipykernel<7.0.0,>=6.26.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (6.29.4)
# Requirement already satisfied: jiwer<4.0.0,>=3.0.3 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (3.0.4)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (3.6)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (3.8.4)
# Requirement already satisfied: mypy-boto3-bedrock<2.0.0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (1.35.20)
# Requirement already satisfied: nltk==3.8.1 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (3.8.1)
# Requirement already satisfied: pandas==2.1.4 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (2.1.4)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (15.0.0)
# Requirement already satisfied: pyfunctional==1.4.3 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (1.4.3)
# Requirement already satisfied: ray==2.23.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (2.23.0)
# Requirement already satisfied: rouge-score<0.2.0,>=0.1.2 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (0.1.2)
# Requirement already satisfied: sagemaker<3.0.0,>=2.225.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (2.229.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (1.4.2)
# Requirement already satisfied: semantic-version==2.10.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (2.10.0)
# Requirement already satisfied: testbook<0.5.0,>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (0.4.2)
# Requirement already satisfied: torch!=2.0.1,!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (2.0.0.post104)
# Requirement already satisfied: transformers<5.0.0,>=4.36.0 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (4.44.2)
# Requirement already satisfied: urllib3>=2.2.2 in /opt/conda/lib/python3.10/site-packages (from fmeval==1.2.0) (2.2.3)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk==3.8.1->fmeval==1.2.0) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk==3.8.1->fmeval==1.2.0) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk==3.8.1->fmeval==1.2.0) (2024.5.15)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk==3.8.1->fmeval==1.2.0) (4.66.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas==2.1.4->fmeval==1.2.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas==2.1.4->fmeval==1.2.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas==2.1.4->fmeval==1.2.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas==2.1.4->fmeval==1.2.0) (2024.1)
# Requirement already satisfied: dill>=0.2.5 in /opt/conda/lib/python3.10/site-packages (from pyfunctional==1.4.3->fmeval==1.2.0) (0.3.8)
# Requirement already satisfied: tabulate<=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pyfunctional==1.4.3->fmeval==1.2.0) (0.9.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (3.15.4)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (4.17.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (23.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (4.24.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (6.0.1)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray==2.23.0->fmeval==1.2.0) (2.32.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->fmeval==1.2.0) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->fmeval==1.2.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->fmeval==1.2.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->fmeval==1.2.0) (4.0.3)
# Requirement already satisfied: datasets>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->fmeval==1.2.0) (2.21.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->fmeval==1.2.0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->fmeval==1.2.0) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->fmeval==1.2.0) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->fmeval==1.2.0) (0.24.7)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->fmeval==1.2.0) (0.18.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (1.6.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.26.0->fmeval==1.2.0) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from IPython->fmeval==1.2.0) (4.9.0)
# Requirement already satisfied: rapidfuzz<4,>=3 in /opt/conda/lib/python3.10/site-packages (from jiwer<4.0.0,>=3.0.3->fmeval==1.2.0) (3.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.3->fmeval==1.2.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.3->fmeval==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.3->fmeval==1.2.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.3->fmeval==1.2.0) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.3->fmeval==1.2.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.3->fmeval==1.2.0) (3.1.2)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score<0.2.0,>=0.1.2->fmeval==1.2.0) (2.1.0)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge-score<0.2.0,>=0.1.2->fmeval==1.2.0) (1.16.0)
# Requirement already satisfied: boto3<2.0,>=1.34.142 in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (1.35.19)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (2.2.1)
# Requirement already satisfied: docker in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (7.1.0)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (6.10.0)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (0.3.2)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (3.11.0)
# Requirement already satisfied: schema in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (2.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.3.1->fmeval==1.2.0) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.3.1->fmeval==1.2.0) (3.5.0)
# Requirement already satisfied: nbformat>=5.0.4 in /opt/conda/lib/python3.10/site-packages (from testbook<0.5.0,>=0.4.2->fmeval==1.2.0) (5.10.4)
# Requirement already satisfied: nbclient>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from testbook<0.5.0,>=0.4.2->fmeval==1.2.0) (0.10.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->fmeval==1.2.0) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->fmeval==1.2.0) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch!=2.0.1,!=2.1.0,>=2.0.0->fmeval==1.2.0) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.36.0->fmeval==1.2.0) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.36.0->fmeval==1.2.0) (0.19.1)
# Requirement already satisfied: botocore<1.36.0,>=1.35.19 in /opt/conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (1.35.19)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (0.10.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (3.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->IPython->fmeval==1.2.0) (0.8.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.0.4->testbook<0.5.0,>=0.4.2->fmeval==1.2.0) (2.20.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.23.0->fmeval==1.2.0) (0.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->IPython->fmeval==1.2.0) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->fmeval==1.2.0) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.23.0->fmeval==1.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.23.0->fmeval==1.2.0) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.23.0->fmeval==1.2.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch!=2.0.1,!=2.1.0,>=2.0.0->fmeval==1.2.0) (2.1.5)
# Requirement already satisfied: ppft>=1.7.6.8 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (1.7.6.8)
# Requirement already satisfied: pox>=0.3.4 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker<3.0.0,>=2.225.0->fmeval==1.2.0) (0.3.4)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->IPython->fmeval==1.2.0) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->IPython->fmeval==1.2.0) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->IPython->fmeval==1.2.0) (0.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch!=2.0.1,!=2.1.0,>=2.0.0->fmeval==1.2.0) (1.3.0)
# Requirement already satisfied: py7zr==0.22.0 in /opt/conda/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: texttable in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (3.20.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (0.16.1)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (1.1.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from py7zr==0.22.0) (6.0.0)
# Requirement already satisfied: langkit[all] in /opt/conda/lib/python3.10/site-packages (0.0.33)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (2.1.4)
# Requirement already satisfied: whylabs-textstat<0.8.0,>=0.7.4 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (0.7.4)
# Requirement already satisfied: whylogs<2.0.0,>=1.3.19 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (1.4.7)
# Requirement already satisfied: datasets<3.0.0,>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (2.21.0)
# Requirement already satisfied: detoxify<0.6.0,>=0.5.2 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (0.5.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (0.4.1)
# Requirement already satisfied: h5py<4.0.0,>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (3.11.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.1.1 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (8.1.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=0.27.6 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (1.45.1)
# Requirement already satisfied: presidio-analyzer<3.0.0,>=2.2.351 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (2.2.355)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (2.7.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (2.0.0.post104)
# Requirement already satisfied: vadersentiment<4.0.0,>=3.3.2 in /opt/conda/lib/python3.10/site-packages (from langkit[all]) (3.3.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (15.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.12.0->langkit[all]) (2023.6.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.24.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.1)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from detoxify<0.6.0,>=0.5.2->langkit[all]) (4.44.2)
# Requirement already satisfied: sentencepiece>=0.1.94 in /opt/conda/lib/python3.10/site-packages (from detoxify<0.6.0,>=0.5.2->langkit[all]) (0.1.99)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from evaluate<0.5.0,>=0.4.0->langkit[all]) (0.18.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.11)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (2024.5.15)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.10.16)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/lib/python3.10/site-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (4.12.2)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in /opt/conda/lib/python3.10/site-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (8.13.45)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /opt/conda/lib/python3.10/site-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.7.4)
# Requirement already satisfied: tldextract in /opt/conda/lib/python3.10/site-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (5.1.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.4.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.11.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (10.3.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->langkit[all]) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->langkit[all]) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->langkit[all]) (3.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from whylabs-textstat<0.8.0,>=0.7.4->langkit[all]) (70.1.1)
# Requirement already satisfied: syllapy in /opt/conda/lib/python3.10/site-packages (from whylabs-textstat<0.8.0,>=0.7.4->langkit[all]) (0.7.2)
# Requirement already satisfied: backoff<3.0.0,>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (2.2.1)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in /opt/conda/lib/python3.10/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (4.24.4)
# Requirement already satisfied: whylabs-client<0.7.0,>=0.6.5 in /opt/conda/lib/python3.10/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (0.6.9)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in /opt/conda/lib/python3.10/site-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.4.1.dev3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->langkit[all]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->langkit[all]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->langkit[all]) (2024.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (4.0.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (0.14.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->langkit[all]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.12.0->langkit[all]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.12.0->langkit[all]) (2.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (6.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.4.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers->detoxify<0.6.0,>=0.5.2->langkit[all]) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers->detoxify<0.6.0,>=0.5.2->langkit[all]) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->langkit[all]) (2.1.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (3.5.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->langkit[all]) (1.3.0)
# Requirement already satisfied: requests-file>=1.4 in /opt/conda/lib/python3.10/site-packages (from tldextract->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.8.4)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.13)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.16.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 👋 Hello, World! Take a quick look at LangKit metrics
#
# In the below code we log a few example prompt/response pairs and send metrics to WhyLabs.

# %%
from langkit import llm_metrics # alternatively use 'light_metrics'
import whylogs as why

# Note: llm_metrics.init() downloads models so this is slow first time.
schema = llm_metrics.init()
# Out:
# [nltk_data] Downloading package vader_lexicon to /home/sagemaker-
# [nltk_data]     user/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# 2024-09-17 16:29:31.037667: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from langkit.whylogs.samples import load_chats, show_first_chat

# Let's look at what's in this toy example:
chats = load_chats()
print(f"There are {len(chats)} records in this toy example data, here's the first one:")
show_first_chat(chats)

results = why.log(chats, name="langkit-sample-chats-all", schema=schema)
# Out:
# There are 50 records in this toy example data, here's the first one:
# prompt: Hello, response: World!
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ⚠️ No session found. Call whylogs.init() to initialize a session and authenticate. See https://docs.whylabs.ai/docs/whylabs-whylogs-init for more information.

# %%
profview = results.view()
profview.to_pandas()
# Out:
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                      47.000005                 47.0
# prompt.aggregate_reading_level              14.000000                 14.0
# prompt.automated_readability_index          38.000003                 38.0
# prompt.character_count                      40.000004                 40.0
# prompt.difficult_words                      11.000000                 11.0
# prompt.flesch_reading_ease                  43.000004                 43.0
# prompt.has_patterns                          2.000000                  2.0
# prompt.jailbreak_similarity                 46.000005                 46.0
# prompt.letter_count                         37.000003                 37.0
# prompt.lexicon_count                        29.000002                 29.0
# prompt.monosyllable_count                   20.000001                 20.0
# prompt.polysyllable_count                    8.000000                  8.0
# prompt.sentence_count                        4.000000                  4.0
# prompt.sentiment_nltk                       28.000002                 28.0
# prompt.syllable_count                       28.000002                 28.0
# prompt.toxicity                             47.000005                 47.0
# response                                    47.000005                 47.0
# response.aggregate_reading_level            20.000001                 20.0
# response.automated_readability_index        43.000004                 43.0
# response.character_count                    40.000004                 40.0
# response.difficult_words                    22.000001                 22.0
# response.flesch_reading_ease                42.000004                 42.0
# response.has_patterns                        4.000000                  4.0
# response.letter_count                       41.000004                 41.0
# response.lexicon_count                      30.000002                 30.0
# response.monosyllable_count                 26.000002                 26.0
# response.polysyllable_count                 16.000001                 16.0
# response.refusal_similarity                 47.000005                 47.0
# response.relevance_to_prompt                47.000005                 47.0
# response.sentence_count                      6.000000                  6.0
# response.sentiment_nltk                     32.000002                 32.0
# response.syllable_count                     33.000003                 33.0
# response.toxicity                           47.000005                 47.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                          47.002352           0
# prompt.aggregate_reading_level                  14.000699           0
# prompt.automated_readability_index              38.001901           0
# prompt.character_count                          40.002001           0
# prompt.difficult_words                          11.000549           0
# prompt.flesch_reading_ease                      43.002151           0
# prompt.has_patterns                              2.000100           0
# prompt.jailbreak_similarity                     46.002302           0
# prompt.letter_count                             37.001851           0
# prompt.lexicon_count                            29.001450           0
# prompt.monosyllable_count                       20.001000           0
# prompt.polysyllable_count                        8.000400           0
# prompt.sentence_count                            4.000200           0
# prompt.sentiment_nltk                           28.001400           0
# prompt.syllable_count                           28.001400           0
# prompt.toxicity                                 47.002352           0
# response                                        47.002352           0
# response.aggregate_reading_level                20.001000           0
# response.automated_readability_index            43.002151           0
# response.character_count                        40.002001           0
# response.difficult_words                        22.001100           0
# response.flesch_reading_ease                    42.002101           0
# response.has_patterns                            4.000200           0
# response.letter_count                           41.002051           0
# response.lexicon_count                          30.001500           0
# response.monosyllable_count                     26.001300           0
# response.polysyllable_count                     16.000799           0
# response.refusal_similarity                     47.002352           0
# response.relevance_to_prompt                    47.002352           0
# response.sentence_count                          6.000300           0
# response.sentiment_nltk                         32.001600           0
# response.syllable_count                         33.001650           0
# response.toxicity                               47.002352           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                      50           0            0
# prompt.aggregate_reading_level              50           0            0
# prompt.automated_readability_index          50           0            0
# prompt.character_count                      50           0            0
# prompt.difficult_words                      50           0            0
# prompt.flesch_reading_ease                  50           0            0
# prompt.has_patterns                         50           0           46
# prompt.jailbreak_similarity                 50           0            0
# prompt.letter_count                         50           0            0
# prompt.lexicon_count                        50           0            0
# prompt.monosyllable_count                   50           0            0
# prompt.polysyllable_count                   50           0            0
# prompt.sentence_count                       50           0            0
# prompt.sentiment_nltk                       50           0            0
# prompt.syllable_count                       50           0            0
# prompt.toxicity                             50           0            0
# response                                    50           0            0
# response.aggregate_reading_level            50           0            0
# response.automated_readability_index        50           0            0
# response.character_count                    50           0            0
# response.difficult_words                    50           0            0
# response.flesch_reading_ease                50           0            0
# response.has_patterns                       50           0           42
# response.letter_count                       50           0            0
# response.lexicon_count                      50           0            0
# response.monosyllable_count                 50           0            0
# response.polysyllable_count                 50           0            0
# response.refusal_similarity                 50           0            0
# response.relevance_to_prompt                50           0            0
# response.sentence_count                     50           0            0
# response.sentiment_nltk                     50           0            0
# response.syllable_count                     50           0            0
# response.toxicity                           50           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN           0.000000
# prompt.aggregate_reading_level               20.000000           7.300000
# prompt.automated_readability_index           31.200000           7.998000
# prompt.character_count                      282.000000          81.280000
# prompt.difficult_words                       24.000000           4.120000
# prompt.flesch_reading_ease                  118.180000          59.130800
# prompt.has_patterns                                NaN           0.000000
# prompt.jailbreak_similarity                   1.000000           0.307416
# prompt.letter_count                         274.000000          78.660000
# prompt.lexicon_count                         59.000000          16.740000
# prompt.monosyllable_count                    48.000000          11.080000
# prompt.polysyllable_count                    16.000000           2.640000
# prompt.sentence_count                         5.000000           1.540000
# prompt.sentiment_nltk                         0.771700           0.022578
# prompt.syllable_count                        97.000000          26.260000
# prompt.toxicity                               0.262324           0.008112
# response                                           NaN           0.000000
# response.aggregate_reading_level             36.000000          10.040000
# response.automated_readability_index         63.300000          13.274000
# response.character_count                   1048.000000         171.920000
# response.difficult_words                     62.000000          10.660000
# response.flesch_reading_ease                206.840000          56.164000
# response.has_patterns                              NaN           0.000000
# response.letter_count                      1019.000000         161.820000
# response.lexicon_count                      156.000000          28.100000
# response.monosyllable_count                  79.000000          14.000000
# response.polysyllable_count                  53.000000           7.380000
# response.refusal_similarity                   0.972949           0.235638
# response.relevance_to_prompt                  0.874570           0.448720
# response.sentence_count                       7.000000           2.120000
# response.sentiment_nltk                       0.985900           0.134154
# response.syllable_count                     350.000000          53.820000
# response.toxicity                             0.829720           0.077705
#
#                                       distribution/median  distribution/min  \
# column
# prompt                                                NaN               NaN
# prompt.aggregate_reading_level                   8.000000          0.000000
# prompt.automated_readability_index               7.400000         -3.000000
# prompt.character_count                          59.000000          6.000000
# prompt.difficult_words                           4.000000          0.000000
# prompt.flesch_reading_ease                      65.730000        -44.260000
# prompt.has_patterns                                   NaN               NaN
# prompt.jailbreak_similarity                      0.277097          0.107413
# prompt.letter_count                             58.000000          5.000000
# prompt.lexicon_count                            12.000000          1.000000
# prompt.monosyllable_count                        8.000000          0.000000
# prompt.polysyllable_count                        2.000000          0.000000
# prompt.sentence_count                            1.000000          1.000000
# prompt.sentiment_nltk                            0.000000         -0.830900
# prompt.syllable_count                           20.000000          2.000000
# prompt.toxicity                                  0.001080          0.000795
# response                                              NaN               NaN
# response.aggregate_reading_level                 9.000000          0.000000
# response.automated_readability_index             8.800000        -11.600000
# response.character_count                        90.000000          1.000000
# response.difficult_words                         5.000000          0.000000
# response.flesch_reading_ease                    61.330000        -72.340000
# response.has_patterns                                 NaN               NaN
# response.letter_count                           81.000000          0.000000
# response.lexicon_count                          15.000000          0.000000
# response.monosyllable_count                      9.000000          0.000000
# response.polysyllable_count                      3.000000          0.000000
# response.refusal_similarity                      0.182912         -0.005942
# response.relevance_to_prompt                     0.453006         -0.018340
# response.sentence_count                          1.000000          1.000000
# response.sentiment_nltk                          0.000000         -0.990900
# response.syllable_count                         26.000000          0.000000
# response.toxicity                                0.001008          0.000744
#
#                                       distribution/n  distribution/q_01  \
# column
# prompt                                             0                NaN
# prompt.aggregate_reading_level                    50           0.000000
# prompt.automated_readability_index                50          -3.000000
# prompt.character_count                            50           6.000000
# prompt.difficult_words                            50           0.000000
# prompt.flesch_reading_ease                        50         -44.260000
# prompt.has_patterns                                0                NaN
# prompt.jailbreak_similarity                       50           0.107413
# prompt.letter_count                               50           5.000000
# prompt.lexicon_count                              50           1.000000
# prompt.monosyllable_count                         50           0.000000
# prompt.polysyllable_count                         50           0.000000
# prompt.sentence_count                             50           1.000000
# prompt.sentiment_nltk                             50          -0.830900
# prompt.syllable_count                             50           2.000000
# prompt.toxicity                                   50           0.000795
# response                                           0                NaN
# response.aggregate_reading_level                  50           0.000000
# response.automated_readability_index              50         -11.600000
# response.character_count                          50           1.000000
# response.difficult_words                          50           0.000000
# response.flesch_reading_ease                      50         -72.340000
# response.has_patterns                              0                NaN
# response.letter_count                             50           0.000000
# response.lexicon_count                            50           0.000000
# response.monosyllable_count                       50           0.000000
# response.polysyllable_count                       50           0.000000
# response.refusal_similarity                       50          -0.005942
# response.relevance_to_prompt                      50          -0.018340
# response.sentence_count                           50           1.000000
# response.sentiment_nltk                           50          -0.990900
# response.syllable_count                           50           0.000000
# response.toxicity                                 50           0.000744
#
#                                       distribution/q_05  distribution/q_10  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 0.000000           0.000000
# prompt.automated_readability_index             2.100000           3.200000
# prompt.character_count                        12.000000          33.000000
# prompt.difficult_words                         0.000000           1.000000
# prompt.flesch_reading_ease                    15.640000          30.230000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.121107           0.148814
# prompt.letter_count                           10.000000          29.000000
# prompt.lexicon_count                           2.000000           5.000000
# prompt.monosyllable_count                      1.000000           4.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                         -0.765000          -0.476700
# prompt.syllable_count                          3.000000           8.000000
# prompt.toxicity                                0.000829           0.000895
# response                                            NaN                NaN
# response.aggregate_reading_level               0.000000           0.000000
# response.automated_readability_index          -2.200000           1.800000
# response.character_count                       4.000000           6.000000
# response.difficult_words                       0.000000           0.000000
# response.flesch_reading_ease                 -31.740000         -13.470000
# response.has_patterns                               NaN                NaN
# response.letter_count                          3.000000           5.000000
# response.lexicon_count                         1.000000           1.000000
# response.monosyllable_count                    0.000000           1.000000
# response.polysyllable_count                    0.000000           0.000000
# response.refusal_similarity                    0.020185           0.054001
# response.relevance_to_prompt                   0.086156           0.126619
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                       -0.990900          -0.493900
# response.syllable_count                        1.000000           1.000000
# response.toxicity                              0.000770           0.000777
#
#                                       distribution/q_25  distribution/q_75  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 5.000000          10.000000
# prompt.automated_readability_index             5.200000          10.400000
# prompt.character_count                        46.000000         103.000000
# prompt.difficult_words                         3.000000           5.000000
# prompt.flesch_reading_ease                    43.390000          76.220000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.211474           0.311718
# prompt.letter_count                           45.000000         101.000000
# prompt.lexicon_count                           8.000000          24.000000
# prompt.monosyllable_count                      5.000000          15.000000
# prompt.polysyllable_count                      1.000000           3.000000
# prompt.sentence_count                          1.000000           2.000000
# prompt.sentiment_nltk                         -0.202300           0.296000
# prompt.syllable_count                         14.000000          32.000000
# prompt.toxicity                                0.000976           0.001430
# response                                            NaN                NaN
# response.aggregate_reading_level               3.000000          15.000000
# response.automated_readability_index           4.800000          20.000000
# response.character_count                      51.000000         196.000000
# response.difficult_words                       1.000000          14.000000
# response.flesch_reading_ease                  21.740000          87.920000
# response.has_patterns                               NaN                NaN
# response.letter_count                         47.000000         170.000000
# response.lexicon_count                         8.000000          34.000000
# response.monosyllable_count                    2.000000          19.000000
# response.polysyllable_count                    1.000000           8.000000
# response.refusal_similarity                    0.113563           0.332653
# response.relevance_to_prompt                   0.207257           0.701286
# response.sentence_count                        1.000000           2.000000
# response.sentiment_nltk                       -0.038700           0.499500
# response.syllable_count                       10.000000          59.000000
# response.toxicity                              0.000827           0.002226
#
#                                       distribution/q_90  distribution/q_95  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          13.000000
# prompt.automated_readability_index            13.100000          15.800000
# prompt.character_count                       167.000000         218.000000
# prompt.difficult_words                         6.000000          10.000000
# prompt.flesch_reading_ease                    85.080000          91.610000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.452144           1.000000
# prompt.letter_count                          164.000000         213.000000
# prompt.lexicon_count                          36.000000          39.000000
# prompt.monosyllable_count                     23.000000          25.000000
# prompt.polysyllable_count                      5.000000           6.000000
# prompt.sentence_count                          3.000000           3.000000
# prompt.sentiment_nltk                          0.526700           0.598400
# prompt.syllable_count                         53.000000          73.000000
# prompt.toxicity                                0.002195           0.002274
# response                                            NaN                NaN
# response.aggregate_reading_level              22.000000          26.000000
# response.automated_readability_index          27.000000          39.900000
# response.character_count                     441.000000         805.000000
# response.difficult_words                      32.000000          53.000000
# response.flesch_reading_ease                 121.220000         145.930000
# response.has_patterns                               NaN                NaN
# response.letter_count                        427.000000         783.000000
# response.lexicon_count                        88.000000         132.000000
# response.monosyllable_count                   33.000000          49.000000
# response.polysyllable_count                   22.000000          43.000000
# response.refusal_similarity                    0.472567           0.684009
# response.relevance_to_prompt                   0.814487           0.847819
# response.sentence_count                        5.000000           6.000000
# response.sentiment_nltk                        0.897900           0.975900
# response.syllable_count                      155.000000         268.000000
# response.toxicity                              0.678064           0.678064
#
#                                       distribution/q_99  distribution/stddev  \
# column
# prompt                                              NaN             0.000000
# prompt.aggregate_reading_level                20.000000             4.210046
# prompt.automated_readability_index            31.200000             5.198449
# prompt.character_count                       282.000000            60.255253
# prompt.difficult_words                        24.000000             3.600680
# prompt.flesch_reading_ease                   118.180000            27.706869
# prompt.has_patterns                                 NaN             0.000000
# prompt.jailbreak_similarity                    1.000000             0.195855
# prompt.letter_count                          274.000000            59.047407
# prompt.lexicon_count                          59.000000            12.804352
# prompt.monosyllable_count                     48.000000             9.467107
# prompt.polysyllable_count                     16.000000             2.848272
# prompt.sentence_count                          5.000000             0.838122
# prompt.sentiment_nltk                          0.771700             0.379258
# prompt.syllable_count                         97.000000            20.423886
# prompt.toxicity                                0.262324             0.038576
# response                                            NaN             0.000000
# response.aggregate_reading_level              36.000000             8.422419
# response.automated_readability_index          63.300000            13.642503
# response.character_count                    1048.000000           229.319031
# response.difficult_words                      62.000000            14.838739
# response.flesch_reading_ease                 206.840000            57.039034
# response.has_patterns                               NaN             0.000000
# response.letter_count                       1019.000000           222.844294
# response.lexicon_count                       156.000000            35.824544
# response.monosyllable_count                   79.000000            16.251844
# response.polysyllable_count                   53.000000            12.417713
# response.refusal_similarity                    0.972949             0.197403
# response.relevance_to_prompt                   0.874570             0.261889
# response.sentence_count                        7.000000             1.802945
# response.sentiment_nltk                        0.985900             0.530116
# response.syllable_count                      350.000000            78.308049
# response.toxicity                              0.829720             0.223712
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.jailbreak_similarity           SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.sentiment_nltk                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# prompt.toxicity                       SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.refusal_similarity           SummaryType.COLUMN              0
# response.relevance_to_prompt          SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.sentiment_nltk               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
# response.toxicity                     SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                      50               0
# prompt.automated_readability_index                  50               0
# prompt.character_count                               0              50
# prompt.difficult_words                               0              50
# prompt.flesch_reading_ease                          50               0
# prompt.has_patterns                                  0               0
# prompt.jailbreak_similarity                         50               0
# prompt.letter_count                                  0              50
# prompt.lexicon_count                                 0              50
# prompt.monosyllable_count                            0              50
# prompt.polysyllable_count                            0              50
# prompt.sentence_count                                0              50
# prompt.sentiment_nltk                               50               0
# prompt.syllable_count                                0              50
# prompt.toxicity                                     50               0
# response                                             0               0
# response.aggregate_reading_level                    50               0
# response.automated_readability_index                50               0
# response.character_count                             0              50
# response.difficult_words                             0              50
# response.flesch_reading_ease                        50               0
# response.has_patterns                                0               0
# response.letter_count                                0              50
# response.lexicon_count                               0              50
# response.monosyllable_count                          0              50
# response.polysyllable_count                          0              50
# response.refusal_similarity                         50               0
# response.relevance_to_prompt                        50               0
# response.sentence_count                              0              50
# response.sentiment_nltk                             50               0
# response.syllable_count                              0              50
# response.toxicity                                   50               0
#
#                                       types/object  types/string  \
# column
# prompt                                           0            50
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             4
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            0             0
# prompt.toxicity                                  0             0
# response                                         0            50
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             8
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.refusal_similarity                      0             0
# response.relevance_to_prompt                     0             0
# response.sentence_count                          0             0
# response.sentiment_nltk                          0             0
# response.syllable_count                          0             0
# response.toxicity                                0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0     282.0       6.0
# prompt.difficult_words                           0      24.0       0.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.jailbreak_similarity                      0       NaN       NaN
# prompt.letter_count                              0     274.0       5.0
# prompt.lexicon_count                             0      59.0       1.0
# prompt.monosyllable_count                        0      48.0       0.0
# prompt.polysyllable_count                        0      16.0       0.0
# prompt.sentence_count                            0       5.0       1.0
# prompt.sentiment_nltk                            0       NaN       NaN
# prompt.syllable_count                            0      97.0       2.0
# prompt.toxicity                                  0       NaN       NaN
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0    1048.0       1.0
# response.difficult_words                         0      62.0       0.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0    1019.0       0.0
# response.lexicon_count                           0     156.0       0.0
# response.monosyllable_count                      0      79.0       0.0
# response.polysyllable_count                      0      53.0       0.0
# response.refusal_similarity                      0       NaN       NaN
# response.relevance_to_prompt                     0       NaN       NaN
# response.sentence_count                          0       7.0       1.0
# response.sentiment_nltk                          0       NaN       NaN
# response.syllable_count                          0     350.0       0.0
# response.toxicity                                0       NaN       NaN
#
#                                                         frequent_items/frequent_strings
# column
# prompt                                                                              NaN
# prompt.aggregate_reading_level                                                      NaN
# prompt.automated_readability_index                                                  NaN
# prompt.character_count                                                              NaN
# prompt.difficult_words                                                              NaN
# prompt.flesch_reading_ease                                                          NaN
# prompt.has_patterns                   [FrequentItem(value='SSN', est=2, upper=2, low...
# prompt.jailbreak_similarity                                                         NaN
# prompt.letter_count                                                                 NaN
# prompt.lexicon_count                                                                NaN
# prompt.monosyllable_count                                                           NaN
# prompt.polysyllable_count                                                           NaN
# prompt.sentence_count                                                               NaN
# prompt.sentiment_nltk                                                               NaN
# prompt.syllable_count                                                               NaN
# prompt.toxicity                                                                     NaN
# response                                                                            NaN
# response.aggregate_reading_level                                                    NaN
# response.automated_readability_index                                                NaN
# response.character_count                                                            NaN
# response.difficult_words                                                            NaN
# response.flesch_reading_ease                                                        NaN
# response.has_patterns                 [FrequentItem(value='SSN', est=3, upper=3, low...
# response.letter_count                                                               NaN
# response.lexicon_count                                                              NaN
# response.monosyllable_count                                                         NaN
# response.polysyllable_count                                                         NaN
# response.refusal_similarity                                                         NaN
# response.relevance_to_prompt                                                        NaN
# response.sentence_count                                                             NaN
# response.sentiment_nltk                                                             NaN
# response.syllable_count                                                             NaN
# response.toxicity                                                                   NaN

# %% [markdown]
# # Text Quality
# Text quality metrics, such as readability, complexity and grade level, can provide important insights into the quality and appropriateness of generated responses. By monitoring these metrics, we can ensure that the Language Model (LLM) outputs are clear, concise, and suitable for the intended audience.
#
# Assessing text complexity and grade level assists in tailoring the generated content to the target audience. By considering factors such as sentence structure, vocabulary choice, and domain-specific requirements, we can ensure that the LLM produces responses that align with the intended reading level and professional context. Additionally, incorporating metrics such as syllable count, word count, and character count allows us to closely monitor the length and composition of the generated text. By setting appropriate limits and guidelines, we can ensure that the responses remain concise, focused, and easily digestible for users.
#
# In langkit, we can compute text quality metrics through the textstat module, which uses the textstat library to compute several different text quality metrics.

# %% [markdown]
# ## flesch_reading_ease
# This method returns the Flesch Reading Ease score of the input text. The score is based on sentence length and word length. Higher scores indicate material that is easier to read; lower numbers mark passages that are more complex.

# %% [markdown]
# ## automated_readability_index
#
# This method returns the Automated Readability Index (ARI) of the input text. ARI is a readability test for English texts that estimates the years of schooling a person needs to understand the text.

# %% [markdown]
# ## aggregate_reading_level
# This method returns the aggregate reading level of the input text as calculated by the textstat library, and includes the metrics above denotes with *

# %% [markdown]
# # Text relevance
#
# Text relevance plays a crucial role in the monitoring of Language Models (LLMs) by providing an objective measure of the similarity between different texts. It serves multiple use cases, including assessing the quality and appropriateness of LLM outputs and providing guardrails to ensure the generation of safe and desired responses.
#
# One use case is computing similarity scores between embeddings generated from prompts and responses, enabling the evaluation of the relevance between them. This helps identify potential issues such as irrelevant or off-topic responses, ensuring that LLM outputs align closely with the intended context. In langkit, we can compute similarity scores between prompt and response pairs using the input_output module.
#
# Another use case is calculating the similarity of prompts and responses against certain topics or known examples, such as jailbreaks or controversial subjects. By comparing the embeddings to these predefined themes, we can establish guardrails to detect potential dangerous or unwanted responses. The similarity scores serve as signals, alerting us to content that may require closer scrutiny or mitigation. In langkit, this can be done through the themes module.
#
# By leveraging text relevance as a monitoring metric for LLMs, we can not only evaluate the quality of generated responses but also establish guardrails to minimize the risk of generating inappropriate or harmful content. This approach enhances the performance, safety, and reliability of LLMs in various applications, providing a valuable tool for responsible AI development.

# %% [markdown]
# ## response.relevance_to_prompt
#
# The response.relevance_to_prompt computed column will contain a similarity score between the prompt and response. The higher the score, the more relevant the response is to the prompt.
#
# The similarity score is computed by calculating the cosine similarity between embeddings generated from both prompt and response. The embeddings are generated using the hugginface's model sentence-transformers/all-MiniLM-L6-v2.

# %% [markdown]
# ## response.refusal_similarity
#
# This group gathers a set of known LLM refusal examples.

# %% [markdown]
# # Security and Privacy
# Monitoring for security and privacy in Language Model (LLM) applications helps ensuring the protection of user data and preventing malicious activities. Several approaches can be employed to strengthen the security and privacy measures within LLM systems.
#
# One approach is to measure text similarity between prompts and responses against known examples of jailbreak attempts, prompt injections, and LLM refusals of service. By comparing the embeddings generated from the text, potential security vulnerabilities and unauthorized access attempts can be identified. This helps in mitigating risks and contributes to the LLM operation within secure boundaries. In langkit, text similarity calculation between prompts/responses and known examples of jailbreak attempts, prompt injections, and LLM refusals of service can be done through the themes module.
#
# Having a prompt injection classifier in place further enhances the security of LLM applications. By detecting and preventing prompt injection attacks, where malicious code or unintended instructions are injected into the prompt, the system can maintain its integrity and protect against unauthorized actions or data leaks. In langkit, prompt injection detection metrics can be computed through the injections module and proactive_injection_detection module.
#
# LLMs are known for their ability to generate non-factual or nonsensical statements, more commonly known as “hallucinations.” This characteristic can undermine trust in many scenarios where factuality is required, such as summarization tasks, generative question answering, and dialogue generations. In langkit, hallucination detection metrics can be computed through the hallucination module.
#
# Another important aspect of security and privacy monitoring involves checking prompts and responses against regex patterns designed to detect sensitive information. These patterns can help identify and flag data such as credit card numbers, telephone numbers, or other types of personally identifiable information (PII). In langkit, regex pattern matching against pattern groups can be done through the regexes module.

# %% [markdown]
# ## prompt.jailbreak_similarity
# This group gathers a set of known jailbreak examples.

# %% [markdown]
# ## prompt.injection
# The prompt.injection column will return the maximum similarity score between the target and a group of known jailbreak attempts and harmful behaviors, which is stored as a vector db using the FAISS package. The higher the score, the more similar it is to a known jailbreak attempt or harmful behavior.
#
# This metric is similar to the jailbreak_similarity from themes module. The difference is that the injection module will compute similarity against a much larger set of examples, but the used encoder and set of examples are not customizable.

# %% [markdown]
# ## has_patterns
# Each value in the string column will be searched by the regexes patterns in pattern_groups.json. If any pattern within a certain group matches, the name of the group will be returned while generating the has_patterns submetric. For instance, if any pattern in the mailing_adress is a match, the value mailing_address will be returned.
#
# The regexes are applied in the order defined in pattern_groups.json. If a value matches multiple patterns, the first pattern that matches will be returned, so the order of the groups in pattern_groups.json is important.

# %% [markdown]
# # Sentiment Analysis
# The use of sentiment analysis for monitoring Language Model (LLM) applications can provide valuable insights into the appropriateness and user engagement of generated responses. By employing sentiment and toxicity classifiers, we can assess the sentiment and detect potentially harmful or inappropriate content within LLM outputs.
#
# Monitoring sentiment allows us to gauge the overall tone and emotional impact of the responses. By analyzing sentiment scores, we can ensure that the LLM is consistently generating appropriate and contextually relevant responses. For instance, in customer service applications, maintaining a positive sentiment ensures a satisfactory user experience.
#
# Additionally, toxicity analysis provides an important measure of the presence of offensive, disrespectful, or harmful language in LLM outputs. By monitoring toxicity scores, we can identify potentially inappropriate content and take necessary actions to mitigate any negative impact.
#
# Analyzing sentiment and toxicity scores in LLM applications also serves other motivations. It enables us to identify potential biases or controversial opinions present in the responses, helping to address concerns related to fairness, inclusivity, and ethical considerations.

# %% [markdown]
# ## sentiment_nltk
# The sentiment_nltk will contain metrics related to the compound sentiment score calculated for each value in the string column. The sentiment score is calculated using nltk's Vader sentiment analyzer. The score ranges from -1 to 1, where -1 is the most negative sentiment and 1 is the most positive sentiment.

# %% [markdown]
# ## toxicity
#
# The toxicity will contain metrics related to the toxicity score calculated for each value in the string column. By default, the toxicity score is calculated using HuggingFace's martin-ha/toxic-comment-model toxicity analyzer. The score ranges from 0 to 1, where 0 is no toxicity and 1 is maximum toxicity.

# %% [markdown]
# # Use LangKit to monitor Meta-Llama-3.1-8B-Instruct model

# %% [markdown]
# Here you will use the HuggingFace datasets package to load the Samsum dataset. The dataset is pre-split into training and test data, so you can simply take that split using the API.

# %%
from datasets import load_dataset

test_dataset  = load_dataset("Samsung/samsum", split="test")

len(test_dataset)
# Out:
# 819

# %% [markdown]
# You can see the test dataset has 819 items in it, and they can be accessed via index. The items include the transcription of the earnings call and a short summary of that dialogue.

# %%
test_dataset[204]
# Out:
# {'id': '13730545',
#  'dialogue': 'Sam: hi, i need a help\r\nSarah fashion: hello how can i help?\r\nSam: Actually i was looking for a nice black dress for my wife, i mean i dont want the in-store product..\r\nSarah fashion: Yes sir, we make dresses on order as per customer requirements.\r\nSam: yeah i saw that option on the web page, actually its a surprise gift for her, but i have no idea what should be the requirements of the dress.\r\nSarah fashion: oh in that case why dont you choose something ready made sir\r\nSam: Actually i want something different for her something she has not seen before\r\nSarah fashion: that nice, do you have any sketch in your mind it would be easier to help \r\nSam: yes that it should be a dress, black in color decent and elegant, and.... thats it :(\r\nSarah fashion: :) dont worry Sir we will try to help you as much as we can but you have to choose between the choices we give you\r\nSam: Sure.\r\nSarah fashion: Would you mind coming to the store? or you want to place order here only?\r\nSam: i was wondering if i could get help and decide i would place order right here...\r\nSarah fashion: Sure sir i am sending you few pictures you can mix and match the designs and that way we would be able to create a new design?\r\nSam: that sounds like a good idea..\r\nSarah fashion: <file_photo><file_photo><file_photo><file_photo><file_photo><file_photo><file_photo><file_photo>\r\nSam: wow! they are all so good but they are available for every one right?\r\nSarah fashion: yes sir!\r\nSam: ok so i want the cut that is in <file_photo> sleeves like this<file_photo> length and buttons <file_photo>\r\nSarah fashion: Nice choice sir, your product number is 898998 now you can order on the website with this product number and the same procedure would be applied to your order.\r\nSam: Thank you so much, i didnt know it was so easy.\r\nSarah fashion:  Your welcome sir, We are glad your liked the service and we hope you like the dress too. \r\nSam: :)',
#  'summary': "Sam wants to buy a custom dress as a surprise for his wife. It should be black and elegant. The store employee sent him some pictures for reference. Sam decided on the features he likes. His product number is 898998 and he will place the order on the company's website."}

# %% [markdown]
# Create the client objects for calling SageMaker APIs, and supply the names of the SageMaker endpoints you created for the base and fine-tuned versions of the model. If you did not deploy both models, you can simply set them to the same endpoint name.

# %%
import sagemaker
import boto3


sess = sagemaker.Session()
boto_session = boto3.session.Session()
region = boto_session.region_name
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# ## Validate endpoint functionality

# %% [markdown]
# ### Reference your base and fine-tuned endpoints
#
# # ***
# # NOTE: PROVIDE YOUR UNIQUE ENDPOINTS HERE OR YOU WILL GET ERRORS
# # ***
#
# __If you will be evaluating a model with swappable LoRA adapters, you can use the same endpoint name for both base and tuned with varying adapter references in your inference payload.__
#
# Omitting the adapter will result in the base model being used without any adapter, and specifying an adapter array with it's name will use that adapter for inference.

# %%
#ENTER YOUR ENDPOINTS HERE
base_endpoint_name = "meta-llama31-8b-instruct-endpoint"
#tuned_endpoint_name = "llama31-8b-lmidist-2024-09-17-02-37-55-645"

# %% [markdown]
# ### As a quick test, you will take a base prompt and sample from the dataset to verify that the endpoints provided will work for the upcoming test runs.
#
# You can also use this as a subjective comparison of the 3 models.

# %%
import json

prompt = f"""
<|begin_of_text|>
<|start_header_id|>system<|end_header_id|>
You are a helpful assistant who is an expert in summarizing conversations.
<|eot_id|>

<|start_header_id|>user<|end_header_id|>
Summarize the provided conversation in 2 sentences.

{test_dataset[0]['dialogue']}

Provide the summary directly, without any introduction or preamble. Do not start the response with "Here is a...".<|eot_id|>

<|start_header_id|>assistant<|end_header_id|>
"""

base_payload = {"inputs": prompt,"parameters": {"do_sample": True,"top_p": 0.9,"temperature": 0.8,"max_new_tokens": 256,},}


base_predictor = sagemaker.Predictor(
    endpoint_name = base_endpoint_name,
    sagemaker_session = sess,
    serializer = sagemaker.serializers.JSONSerializer(),
    deserializer = sagemaker.deserializers.JSONDeserializer(),
)

base_predictor_response = base_predictor.predict(base_payload)

print(f"Base Model:\n{base_predictor_response['generated_text']}")
print("\n ================ \n")
# Out:
# Base Model:
# Hannah asked Amanda for Betty's phone number, but Amanda couldn't find it, suggesting she ask Larry who had recently contacted Betty. Amanda encouraged Hannah to text Larry, despite Hannah's initial hesitation.
#
#  ================

# %% [markdown]
# ## ML Monitoring for LLMs in WhyLabs
#
#
# To send LangKit profiles to WhyLabs we will need three pieces of information:
#
# - API token
# - Organization ID
# - Dataset ID (or model-id)
#
# Go to [https://whylabs.ai/free](https://whylabs.ai/free) and grab a free account. You can follow along with the quick start examples or skip them if you'd like to follow this example immediately.
#
# 1. Create a new project and note its ID (if it's a model project, it will look like `model-xxxx`)
# 2. Create an API token from the "Access Tokens" tab
# 3. Copy your org ID from the same "Access Tokens" tab
#
# Replace the placeholder string values with your WhyLabs API Keys below:

# %% [markdown]
# ![](./1_access-token.png)

# %%
import pandas as pd
import os
import whylogs as why

#os.environ["WHYLABS_DEFAULT_ORG_ID"] = "xxx" # ORG-ID is case sensitive
#os.environ["WHYLABS_API_KEY"] = "xxx" # API-KEY
#os.environ["WHYLABS_DEFAULT_DATASET_ID"] = "xxx" # MODEL-ID


os.environ["WHYLABS_DEFAULT_ORG_ID"] = "org-segrKk" # ORG-ID is case sensitive
os.environ["WHYLABS_API_KEY"] = "pXeBXBtIm8.vLXWBjiVlvL3orjBRtJsQ6JJ91lD5jDTKgJreRAFclAXrCLHFSxq2:org-segrKk"
os.environ["WHYLABS_DEFAULT_DATASET_ID"] = "model-2"

# %%
from whylogs.api.writer.whylabs import WhyLabsWriter
from langkit import llm_metrics # alternatively use 'light_metrics'
import whylogs as why


# Set to show all columns in dataframe
pd.set_option("display.max_columns", None)

# Note: llm_metrics.init() downloads models so this is slow first time.
schema = llm_metrics.init()
why.init()
# Out:
# Initializing session with config /home/sagemaker-user/.config/whylogs/config.ini
#
# ✅ Using session type: WHYLABS
#  ⤷ org id: org-segrKk
#  ⤷ api key: pXeBXBtIm8
#  ⤷ default dataset: model-2
#
# In production, you should pass the api key as an environment variable WHYLABS_API_KEY, the org id as WHYLABS_DEFAULT_ORG_ID, and the default dataset id as WHYLABS_DEFAULT_DATASET_ID.

# %% [markdown]
# ### Create & Inspect  Language Metrics with LangKit
#
# LangKit provides a toolkit of metrics for LLM applications, lets initialize them and create a profile of the data that can be viewed in WhyLabs for quick analysis.

# %%
base_prompt = f"""
    <|begin_of_text|><|start_header_id|>user<|end_header_id|>
    {{question}}
    <|eot_id|><|start_header_id|>assistant<|end_header_id|>
    
"""

# %%
def predict_fn(prompt, question):
    
    response = base_predictor.predict({
	"inputs": prompt,
    "parameters": {
        "n_predict": -1,
        "temperature": 0.2,
        "top_p": 0.9,
        "stop": ["<|start_header_id|>", "<|eot_id|>", "<|start_header_id|>user<|end_header_id|>", "assistant"]
    }
    })

    #print(response)

    # parse response text
    resp = response['generated_text']
    
    rhi = resp.rfind('<|end_header_id|>')
    rhi = rhi + 1
    
    resp_mod = resp[rhi:]

    # remove \t\n
    resp_mod = resp_mod.replace('\n', '')
    resp_mod = resp_mod.replace('\t', '')

    question_mod = question.replace('\n', '')
    question_mod = question_mod.replace('\t', '')
    question_mod = question_mod.replace('\r', '')


    prompt_and_response = {
      "prompt": question_mod,
      "response": resp_mod
    }
    
    return prompt_and_response

# %%
question="What is the context window of Anthropic Claude 2.1 model?"
prompt = base_prompt.format(question=question)

prompt_and_response = predict_fn(prompt,question)
print(prompt_and_response)
# Out:
# {'prompt': 'What is the context window of Anthropic Claude 2.1 model?', 'response': 'The context window of the Anthropic Claude 2.1 model refers to the amount of text that the model can consider when generating a response. The'}

# %%
prompt_template = f"""
<|begin_of_text|>
<|start_header_id|>system<|end_header_id|>
You are a helpful assistant who is an expert in summarizing conversations.
<|eot_id|>

<|start_header_id|>user<|end_header_id|>
Summarize the provided conversation in 2 sentences.

{{question}}

Provide the summary directly, without any introduction or preamble. Do not start the response with "Here is a...".<|eot_id|>

<|start_header_id|>assistant<|end_header_id|>
"""

# %%
question=test_dataset[0]['dialogue']
prompt = prompt_template.format(question=question)

prompt_and_response = predict_fn(prompt,question)
print(prompt_and_response)
# Out:
# {'prompt': "Hannah: Hey, do you have Betty's number?Amanda: Lemme checkHannah: <file_gif>Amanda: Sorry, can't find it.Amanda: Ask LarryAmanda: He called her last time we were at the park togetherHannah: I don't know him wellHannah: <file_gif>Amanda: Don't be shy, he's very niceHannah: If you say so..Hannah: I'd rather you texted himAmanda: Just text him 🙂Hannah: Urgh.. AlrightHannah: ByeAmanda: Bye bye", 'response': "Hannah asked Amanda for Betty's phone number, but Amanda couldn't find it, suggesting she ask Larry who had recently spoken to her. Hannah was"}

# %%
profile = why.log(prompt_and_response, schema=schema).profile()
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000

# %%
profview = profile.view()
profview.to_pandas()
# Out:
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                            1.0                  1.0
# prompt.aggregate_reading_level                    1.0                  1.0
# prompt.automated_readability_index                1.0                  1.0
# prompt.character_count                            1.0                  1.0
# prompt.difficult_words                            1.0                  1.0
# prompt.flesch_reading_ease                        1.0                  1.0
# prompt.has_patterns                               NaN                  NaN
# prompt.jailbreak_similarity                       1.0                  1.0
# prompt.letter_count                               1.0                  1.0
# prompt.lexicon_count                              1.0                  1.0
# prompt.monosyllable_count                         1.0                  1.0
# prompt.polysyllable_count                         1.0                  1.0
# prompt.sentence_count                             1.0                  1.0
# prompt.sentiment_nltk                             1.0                  1.0
# prompt.syllable_count                             1.0                  1.0
# prompt.toxicity                                   1.0                  1.0
# response                                          1.0                  1.0
# response.aggregate_reading_level                  1.0                  1.0
# response.automated_readability_index              1.0                  1.0
# response.character_count                          1.0                  1.0
# response.difficult_words                          1.0                  1.0
# response.flesch_reading_ease                      1.0                  1.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             1.0                  1.0
# response.lexicon_count                            1.0                  1.0
# response.monosyllable_count                       1.0                  1.0
# response.polysyllable_count                       1.0                  1.0
# response.refusal_similarity                       1.0                  1.0
# response.relevance_to_prompt                      1.0                  1.0
# response.sentence_count                           1.0                  1.0
# response.sentiment_nltk                           1.0                  1.0
# response.syllable_count                           1.0                  1.0
# response.toxicity                                 1.0                  1.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                            1.00005           0
# prompt.aggregate_reading_level                    1.00005           0
# prompt.automated_readability_index                1.00005           0
# prompt.character_count                            1.00005           0
# prompt.difficult_words                            1.00005           0
# prompt.flesch_reading_ease                        1.00005           0
# prompt.has_patterns                                   NaN           0
# prompt.jailbreak_similarity                       1.00005           0
# prompt.letter_count                               1.00005           0
# prompt.lexicon_count                              1.00005           0
# prompt.monosyllable_count                         1.00005           0
# prompt.polysyllable_count                         1.00005           0
# prompt.sentence_count                             1.00005           0
# prompt.sentiment_nltk                             1.00005           0
# prompt.syllable_count                             1.00005           0
# prompt.toxicity                                   1.00005           0
# response                                          1.00005           0
# response.aggregate_reading_level                  1.00005           0
# response.automated_readability_index              1.00005           0
# response.character_count                          1.00005           0
# response.difficult_words                          1.00005           0
# response.flesch_reading_ease                      1.00005           0
# response.has_patterns                                 NaN           0
# response.letter_count                             1.00005           0
# response.lexicon_count                            1.00005           0
# response.monosyllable_count                       1.00005           0
# response.polysyllable_count                       1.00005           0
# response.refusal_similarity                       1.00005           0
# response.relevance_to_prompt                      1.00005           0
# response.sentence_count                           1.00005           0
# response.sentiment_nltk                           1.00005           0
# response.syllable_count                           1.00005           0
# response.toxicity                                 1.00005           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                       1           0            0
# prompt.aggregate_reading_level               1           0            0
# prompt.automated_readability_index           1           0            0
# prompt.character_count                       1           0            0
# prompt.difficult_words                       1           0            0
# prompt.flesch_reading_ease                   1           0            0
# prompt.has_patterns                          1           0            1
# prompt.jailbreak_similarity                  1           0            0
# prompt.letter_count                          1           0            0
# prompt.lexicon_count                         1           0            0
# prompt.monosyllable_count                    1           0            0
# prompt.polysyllable_count                    1           0            0
# prompt.sentence_count                        1           0            0
# prompt.sentiment_nltk                        1           0            0
# prompt.syllable_count                        1           0            0
# prompt.toxicity                              1           0            0
# response                                     1           0            0
# response.aggregate_reading_level             1           0            0
# response.automated_readability_index         1           0            0
# response.character_count                     1           0            0
# response.difficult_words                     1           0            0
# response.flesch_reading_ease                 1           0            0
# response.has_patterns                        1           0            1
# response.letter_count                        1           0            0
# response.lexicon_count                       1           0            0
# response.monosyllable_count                  1           0            0
# response.polysyllable_count                  1           0            0
# response.refusal_similarity                  1           0            0
# response.relevance_to_prompt                 1           0            0
# response.sentence_count                      1           0            0
# response.sentiment_nltk                      1           0            0
# response.syllable_count                      1           0            0
# response.toxicity                            1           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN           0.000000
# prompt.aggregate_reading_level               12.000000          12.000000
# prompt.automated_readability_index           12.100000          12.100000
# prompt.character_count                      337.000000         337.000000
# prompt.difficult_words                       13.000000          13.000000
# prompt.flesch_reading_ease                   42.980000          42.980000
# prompt.has_patterns                                NaN                NaN
# prompt.jailbreak_similarity                   0.276274           0.276274
# prompt.letter_count                         302.000000         302.000000
# prompt.lexicon_count                         57.000000          57.000000
# prompt.monosyllable_count                    37.000000          37.000000
# prompt.polysyllable_count                    13.000000          13.000000
# prompt.sentence_count                         5.000000           5.000000
# prompt.sentiment_nltk                         0.112900           0.112900
# prompt.syllable_count                       105.000000         105.000000
# prompt.toxicity                               0.020406           0.020406
# response                                           NaN           0.000000
# response.aggregate_reading_level             11.000000          11.000000
# response.automated_readability_index         13.900000          13.900000
# response.character_count                    119.000000         119.000000
# response.difficult_words                      7.000000           7.000000
# response.flesch_reading_ease                 55.580000          55.580000
# response.has_patterns                              NaN                NaN
# response.letter_count                       114.000000         114.000000
# response.lexicon_count                       24.000000          24.000000
# response.monosyllable_count                  14.000000          14.000000
# response.polysyllable_count                   3.000000           3.000000
# response.refusal_similarity                   0.186855           0.186855
# response.relevance_to_prompt                  0.768668           0.768668
# response.sentence_count                       1.000000           1.000000
# response.sentiment_nltk                       0.038700           0.038700
# response.syllable_count                      37.000000          37.000000
# response.toxicity                             0.001970           0.001970
#
#                                       distribution/median  distribution/min  \
# column
# prompt                                                NaN               NaN
# prompt.aggregate_reading_level                  12.000000         12.000000
# prompt.automated_readability_index              12.100000         12.100000
# prompt.character_count                         337.000000        337.000000
# prompt.difficult_words                          13.000000         13.000000
# prompt.flesch_reading_ease                      42.980000         42.980000
# prompt.has_patterns                                   NaN               NaN
# prompt.jailbreak_similarity                      0.276274          0.276274
# prompt.letter_count                            302.000000        302.000000
# prompt.lexicon_count                            57.000000         57.000000
# prompt.monosyllable_count                       37.000000         37.000000
# prompt.polysyllable_count                       13.000000         13.000000
# prompt.sentence_count                            5.000000          5.000000
# prompt.sentiment_nltk                            0.112900          0.112900
# prompt.syllable_count                          105.000000        105.000000
# prompt.toxicity                                  0.020406          0.020406
# response                                              NaN               NaN
# response.aggregate_reading_level                11.000000         11.000000
# response.automated_readability_index            13.900000         13.900000
# response.character_count                       119.000000        119.000000
# response.difficult_words                         7.000000          7.000000
# response.flesch_reading_ease                    55.580000         55.580000
# response.has_patterns                                 NaN               NaN
# response.letter_count                          114.000000        114.000000
# response.lexicon_count                          24.000000         24.000000
# response.monosyllable_count                     14.000000         14.000000
# response.polysyllable_count                      3.000000          3.000000
# response.refusal_similarity                      0.186855          0.186855
# response.relevance_to_prompt                     0.768668          0.768668
# response.sentence_count                          1.000000          1.000000
# response.sentiment_nltk                          0.038700          0.038700
# response.syllable_count                         37.000000         37.000000
# response.toxicity                                0.001970          0.001970
#
#                                       distribution/n  distribution/q_01  \
# column
# prompt                                           0.0                NaN
# prompt.aggregate_reading_level                   1.0          12.000000
# prompt.automated_readability_index               1.0          12.100000
# prompt.character_count                           1.0         337.000000
# prompt.difficult_words                           1.0          13.000000
# prompt.flesch_reading_ease                       1.0          42.980000
# prompt.has_patterns                              NaN                NaN
# prompt.jailbreak_similarity                      1.0           0.276274
# prompt.letter_count                              1.0         302.000000
# prompt.lexicon_count                             1.0          57.000000
# prompt.monosyllable_count                        1.0          37.000000
# prompt.polysyllable_count                        1.0          13.000000
# prompt.sentence_count                            1.0           5.000000
# prompt.sentiment_nltk                            1.0           0.112900
# prompt.syllable_count                            1.0         105.000000
# prompt.toxicity                                  1.0           0.020406
# response                                         0.0                NaN
# response.aggregate_reading_level                 1.0          11.000000
# response.automated_readability_index             1.0          13.900000
# response.character_count                         1.0         119.000000
# response.difficult_words                         1.0           7.000000
# response.flesch_reading_ease                     1.0          55.580000
# response.has_patterns                            NaN                NaN
# response.letter_count                            1.0         114.000000
# response.lexicon_count                           1.0          24.000000
# response.monosyllable_count                      1.0          14.000000
# response.polysyllable_count                      1.0           3.000000
# response.refusal_similarity                      1.0           0.186855
# response.relevance_to_prompt                     1.0           0.768668
# response.sentence_count                          1.0           1.000000
# response.sentiment_nltk                          1.0           0.038700
# response.syllable_count                          1.0          37.000000
# response.toxicity                                1.0           0.001970
#
#                                       distribution/q_05  distribution/q_10  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            12.100000          12.100000
# prompt.character_count                       337.000000         337.000000
# prompt.difficult_words                        13.000000          13.000000
# prompt.flesch_reading_ease                    42.980000          42.980000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.276274           0.276274
# prompt.letter_count                          302.000000         302.000000
# prompt.lexicon_count                          57.000000          57.000000
# prompt.monosyllable_count                     37.000000          37.000000
# prompt.polysyllable_count                     13.000000          13.000000
# prompt.sentence_count                          5.000000           5.000000
# prompt.sentiment_nltk                          0.112900           0.112900
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.020406           0.020406
# response                                            NaN                NaN
# response.aggregate_reading_level              11.000000          11.000000
# response.automated_readability_index          13.900000          13.900000
# response.character_count                     119.000000         119.000000
# response.difficult_words                       7.000000           7.000000
# response.flesch_reading_ease                  55.580000          55.580000
# response.has_patterns                               NaN                NaN
# response.letter_count                        114.000000         114.000000
# response.lexicon_count                        24.000000          24.000000
# response.monosyllable_count                   14.000000          14.000000
# response.polysyllable_count                    3.000000           3.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.768668           0.768668
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                        0.038700           0.038700
# response.syllable_count                       37.000000          37.000000
# response.toxicity                              0.001970           0.001970
#
#                                       distribution/q_25  distribution/q_75  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            12.100000          12.100000
# prompt.character_count                       337.000000         337.000000
# prompt.difficult_words                        13.000000          13.000000
# prompt.flesch_reading_ease                    42.980000          42.980000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.276274           0.276274
# prompt.letter_count                          302.000000         302.000000
# prompt.lexicon_count                          57.000000          57.000000
# prompt.monosyllable_count                     37.000000          37.000000
# prompt.polysyllable_count                     13.000000          13.000000
# prompt.sentence_count                          5.000000           5.000000
# prompt.sentiment_nltk                          0.112900           0.112900
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.020406           0.020406
# response                                            NaN                NaN
# response.aggregate_reading_level              11.000000          11.000000
# response.automated_readability_index          13.900000          13.900000
# response.character_count                     119.000000         119.000000
# response.difficult_words                       7.000000           7.000000
# response.flesch_reading_ease                  55.580000          55.580000
# response.has_patterns                               NaN                NaN
# response.letter_count                        114.000000         114.000000
# response.lexicon_count                        24.000000          24.000000
# response.monosyllable_count                   14.000000          14.000000
# response.polysyllable_count                    3.000000           3.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.768668           0.768668
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                        0.038700           0.038700
# response.syllable_count                       37.000000          37.000000
# response.toxicity                              0.001970           0.001970
#
#                                       distribution/q_90  distribution/q_95  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            12.100000          12.100000
# prompt.character_count                       337.000000         337.000000
# prompt.difficult_words                        13.000000          13.000000
# prompt.flesch_reading_ease                    42.980000          42.980000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.276274           0.276274
# prompt.letter_count                          302.000000         302.000000
# prompt.lexicon_count                          57.000000          57.000000
# prompt.monosyllable_count                     37.000000          37.000000
# prompt.polysyllable_count                     13.000000          13.000000
# prompt.sentence_count                          5.000000           5.000000
# prompt.sentiment_nltk                          0.112900           0.112900
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.020406           0.020406
# response                                            NaN                NaN
# response.aggregate_reading_level              11.000000          11.000000
# response.automated_readability_index          13.900000          13.900000
# response.character_count                     119.000000         119.000000
# response.difficult_words                       7.000000           7.000000
# response.flesch_reading_ease                  55.580000          55.580000
# response.has_patterns                               NaN                NaN
# response.letter_count                        114.000000         114.000000
# response.lexicon_count                        24.000000          24.000000
# response.monosyllable_count                   14.000000          14.000000
# response.polysyllable_count                    3.000000           3.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.768668           0.768668
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                        0.038700           0.038700
# response.syllable_count                       37.000000          37.000000
# response.toxicity                              0.001970           0.001970
#
#                                       distribution/q_99  distribution/stddev  \
# column
# prompt                                              NaN                  0.0
# prompt.aggregate_reading_level                12.000000                  0.0
# prompt.automated_readability_index            12.100000                  0.0
# prompt.character_count                       337.000000                  0.0
# prompt.difficult_words                        13.000000                  0.0
# prompt.flesch_reading_ease                    42.980000                  0.0
# prompt.has_patterns                                 NaN                  NaN
# prompt.jailbreak_similarity                    0.276274                  0.0
# prompt.letter_count                          302.000000                  0.0
# prompt.lexicon_count                          57.000000                  0.0
# prompt.monosyllable_count                     37.000000                  0.0
# prompt.polysyllable_count                     13.000000                  0.0
# prompt.sentence_count                          5.000000                  0.0
# prompt.sentiment_nltk                          0.112900                  0.0
# prompt.syllable_count                        105.000000                  0.0
# prompt.toxicity                                0.020406                  0.0
# response                                            NaN                  0.0
# response.aggregate_reading_level              11.000000                  0.0
# response.automated_readability_index          13.900000                  0.0
# response.character_count                     119.000000                  0.0
# response.difficult_words                       7.000000                  0.0
# response.flesch_reading_ease                  55.580000                  0.0
# response.has_patterns                               NaN                  NaN
# response.letter_count                        114.000000                  0.0
# response.lexicon_count                        24.000000                  0.0
# response.monosyllable_count                   14.000000                  0.0
# response.polysyllable_count                    3.000000                  0.0
# response.refusal_similarity                    0.186855                  0.0
# response.relevance_to_prompt                   0.768668                  0.0
# response.sentence_count                        1.000000                  0.0
# response.sentiment_nltk                        0.038700                  0.0
# response.syllable_count                       37.000000                  0.0
# response.toxicity                              0.001970                  0.0
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.jailbreak_similarity           SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.sentiment_nltk                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# prompt.toxicity                       SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.refusal_similarity           SummaryType.COLUMN              0
# response.relevance_to_prompt          SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.sentiment_nltk               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
# response.toxicity                     SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                       1               0
# prompt.automated_readability_index                   1               0
# prompt.character_count                               0               1
# prompt.difficult_words                               0               1
# prompt.flesch_reading_ease                           1               0
# prompt.has_patterns                                  0               0
# prompt.jailbreak_similarity                          1               0
# prompt.letter_count                                  0               1
# prompt.lexicon_count                                 0               1
# prompt.monosyllable_count                            0               1
# prompt.polysyllable_count                            0               1
# prompt.sentence_count                                0               1
# prompt.sentiment_nltk                                1               0
# prompt.syllable_count                                0               1
# prompt.toxicity                                      1               0
# response                                             0               0
# response.aggregate_reading_level                     1               0
# response.automated_readability_index                 1               0
# response.character_count                             0               1
# response.difficult_words                             0               1
# response.flesch_reading_ease                         1               0
# response.has_patterns                                0               0
# response.letter_count                                0               1
# response.lexicon_count                               0               1
# response.monosyllable_count                          0               1
# response.polysyllable_count                          0               1
# response.refusal_similarity                          1               0
# response.relevance_to_prompt                         1               0
# response.sentence_count                              0               1
# response.sentiment_nltk                              1               0
# response.syllable_count                              0               1
# response.toxicity                                    1               0
#
#                                       types/object  types/string  \
# column
# prompt                                           0             1
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            0             0
# prompt.toxicity                                  0             0
# response                                         0             1
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             0
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.refusal_similarity                      0             0
# response.relevance_to_prompt                     0             0
# response.sentence_count                          0             0
# response.sentiment_nltk                          0             0
# response.syllable_count                          0             0
# response.toxicity                                0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0     337.0     337.0
# prompt.difficult_words                           0      13.0      13.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.jailbreak_similarity                      0       NaN       NaN
# prompt.letter_count                              0     302.0     302.0
# prompt.lexicon_count                             0      57.0      57.0
# prompt.monosyllable_count                        0      37.0      37.0
# prompt.polysyllable_count                        0      13.0      13.0
# prompt.sentence_count                            0       5.0       5.0
# prompt.sentiment_nltk                            0       NaN       NaN
# prompt.syllable_count                            0     105.0     105.0
# prompt.toxicity                                  0       NaN       NaN
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0     119.0     119.0
# response.difficult_words                         0       7.0       7.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0     114.0     114.0
# response.lexicon_count                           0      24.0      24.0
# response.monosyllable_count                      0      14.0      14.0
# response.polysyllable_count                      0       3.0       3.0
# response.refusal_similarity                      0       NaN       NaN
# response.relevance_to_prompt                     0       NaN       NaN
# response.sentence_count                          0       1.0       1.0
# response.sentiment_nltk                          0       NaN       NaN
# response.syllable_count                          0      37.0      37.0
# response.toxicity                                0       NaN       NaN
#
#                                      frequent_items/frequent_strings
# column
# prompt                                                           NaN
# prompt.aggregate_reading_level                                   NaN
# prompt.automated_readability_index                               NaN
# prompt.character_count                                           NaN
# prompt.difficult_words                                           NaN
# prompt.flesch_reading_ease                                       NaN
# prompt.has_patterns                                               []
# prompt.jailbreak_similarity                                      NaN
# prompt.letter_count                                              NaN
# prompt.lexicon_count                                             NaN
# prompt.monosyllable_count                                        NaN
# prompt.polysyllable_count                                        NaN
# prompt.sentence_count                                            NaN
# prompt.sentiment_nltk                                            NaN
# prompt.syllable_count                                            NaN
# prompt.toxicity                                                  NaN
# response                                                         NaN
# response.aggregate_reading_level                                 NaN
# response.automated_readability_index                             NaN
# response.character_count                                         NaN
# response.difficult_words                                         NaN
# response.flesch_reading_ease                                     NaN
# response.has_patterns                                             []
# response.letter_count                                            NaN
# response.lexicon_count                                           NaN
# response.monosyllable_count                                      NaN
# response.polysyllable_count                                      NaN
# response.refusal_similarity                                      NaN
# response.relevance_to_prompt                                     NaN
# response.sentence_count                                          NaN
# response.sentiment_nltk                                          NaN
# response.syllable_count                                          NaN
# response.toxicity                                                NaN

# %% [markdown]
# ## Batch Monitor LLM prompt and response

# %%
profile = why.log(prompt_and_response, schema=schema).profile()
profview = profile.view()
profview.to_pandas()
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                            1.0                  1.0
# prompt.aggregate_reading_level                    1.0                  1.0
# prompt.automated_readability_index                1.0                  1.0
# prompt.character_count                            1.0                  1.0
# prompt.difficult_words                            1.0                  1.0
# prompt.flesch_reading_ease                        1.0                  1.0
# prompt.has_patterns                               NaN                  NaN
# prompt.jailbreak_similarity                       1.0                  1.0
# prompt.letter_count                               1.0                  1.0
# prompt.lexicon_count                              1.0                  1.0
# prompt.monosyllable_count                         1.0                  1.0
# prompt.polysyllable_count                         1.0                  1.0
# prompt.sentence_count                             1.0                  1.0
# prompt.sentiment_nltk                             1.0                  1.0
# prompt.syllable_count                             1.0                  1.0
# prompt.toxicity                                   1.0                  1.0
# response                                          1.0                  1.0
# response.aggregate_reading_level                  1.0                  1.0
# response.automated_readability_index              1.0                  1.0
# response.character_count                          1.0                  1.0
# response.difficult_words                          1.0                  1.0
# response.flesch_reading_ease                      1.0                  1.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             1.0                  1.0
# response.lexicon_count                            1.0                  1.0
# response.monosyllable_count                       1.0                  1.0
# response.polysyllable_count                       1.0                  1.0
# response.refusal_similarity                       1.0                  1.0
# response.relevance_to_prompt                      1.0                  1.0
# response.sentence_count                           1.0                  1.0
# response.sentiment_nltk                           1.0                  1.0
# response.syllable_count                           1.0                  1.0
# response.toxicity                                 1.0                  1.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                            1.00005           0
# prompt.aggregate_reading_level                    1.00005           0
# prompt.automated_readability_index                1.00005           0
# prompt.character_count                            1.00005           0
# prompt.difficult_words                            1.00005           0
# prompt.flesch_reading_ease                        1.00005           0
# prompt.has_patterns                                   NaN           0
# prompt.jailbreak_similarity                       1.00005           0
# prompt.letter_count                               1.00005           0
# prompt.lexicon_count                              1.00005           0
# prompt.monosyllable_count                         1.00005           0
# prompt.polysyllable_count                         1.00005           0
# prompt.sentence_count                             1.00005           0
# prompt.sentiment_nltk                             1.00005           0
# prompt.syllable_count                             1.00005           0
# prompt.toxicity                                   1.00005           0
# response                                          1.00005           0
# response.aggregate_reading_level                  1.00005           0
# response.automated_readability_index              1.00005           0
# response.character_count                          1.00005           0
# response.difficult_words                          1.00005           0
# response.flesch_reading_ease                      1.00005           0
# response.has_patterns                                 NaN           0
# response.letter_count                             1.00005           0
# response.lexicon_count                            1.00005           0
# response.monosyllable_count                       1.00005           0
# response.polysyllable_count                       1.00005           0
# response.refusal_similarity                       1.00005           0
# response.relevance_to_prompt                      1.00005           0
# response.sentence_count                           1.00005           0
# response.sentiment_nltk                           1.00005           0
# response.syllable_count                           1.00005           0
# response.toxicity                                 1.00005           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                       1           0            0
# prompt.aggregate_reading_level               1           0            0
# prompt.automated_readability_index           1           0            0
# prompt.character_count                       1           0            0
# prompt.difficult_words                       1           0            0
# prompt.flesch_reading_ease                   1           0            0
# prompt.has_patterns                          1           0            1
# prompt.jailbreak_similarity                  1           0            0
# prompt.letter_count                          1           0            0
# prompt.lexicon_count                         1           0            0
# prompt.monosyllable_count                    1           0            0
# prompt.polysyllable_count                    1           0            0
# prompt.sentence_count                        1           0            0
# prompt.sentiment_nltk                        1           0            0
# prompt.syllable_count                        1           0            0
# prompt.toxicity                              1           0            0
# response                                     1           0            0
# response.aggregate_reading_level             1           0            0
# response.automated_readability_index         1           0            0
# response.character_count                     1           0            0
# response.difficult_words                     1           0            0
# response.flesch_reading_ease                 1           0            0
# response.has_patterns                        1           0            1
# response.letter_count                        1           0            0
# response.lexicon_count                       1           0            0
# response.monosyllable_count                  1           0            0
# response.polysyllable_count                  1           0            0
# response.refusal_similarity                  1           0            0
# response.relevance_to_prompt                 1           0            0
# response.sentence_count                      1           0            0
# response.sentiment_nltk                      1           0            0
# response.syllable_count                      1           0            0
# response.toxicity                            1           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN           0.000000
# prompt.aggregate_reading_level               12.000000          12.000000
# prompt.automated_readability_index           12.100000          12.100000
# prompt.character_count                      337.000000         337.000000
# prompt.difficult_words                       13.000000          13.000000
# prompt.flesch_reading_ease                   42.980000          42.980000
# prompt.has_patterns                                NaN                NaN
# prompt.jailbreak_similarity                   0.276274           0.276274
# prompt.letter_count                         302.000000         302.000000
# prompt.lexicon_count                         57.000000          57.000000
# prompt.monosyllable_count                    37.000000          37.000000
# prompt.polysyllable_count                    13.000000          13.000000
# prompt.sentence_count                         5.000000           5.000000
# prompt.sentiment_nltk                         0.112900           0.112900
# prompt.syllable_count                       105.000000         105.000000
# prompt.toxicity                               0.020406           0.020406
# response                                           NaN           0.000000
# response.aggregate_reading_level             11.000000          11.000000
# response.automated_readability_index         13.900000          13.900000
# response.character_count                    119.000000         119.000000
# response.difficult_words                      7.000000           7.000000
# response.flesch_reading_ease                 55.580000          55.580000
# response.has_patterns                              NaN                NaN
# response.letter_count                       114.000000         114.000000
# response.lexicon_count                       24.000000          24.000000
# response.monosyllable_count                  14.000000          14.000000
# response.polysyllable_count                   3.000000           3.000000
# response.refusal_similarity                   0.186855           0.186855
# response.relevance_to_prompt                  0.768668           0.768668
# response.sentence_count                       1.000000           1.000000
# response.sentiment_nltk                       0.038700           0.038700
# response.syllable_count                      37.000000          37.000000
# response.toxicity                             0.001970           0.001970
#
#                                       distribution/median  distribution/min  \
# column
# prompt                                                NaN               NaN
# prompt.aggregate_reading_level                  12.000000         12.000000
# prompt.automated_readability_index              12.100000         12.100000
# prompt.character_count                         337.000000        337.000000
# prompt.difficult_words                          13.000000         13.000000
# prompt.flesch_reading_ease                      42.980000         42.980000
# prompt.has_patterns                                   NaN               NaN
# prompt.jailbreak_similarity                      0.276274          0.276274
# prompt.letter_count                            302.000000        302.000000
# prompt.lexicon_count                            57.000000         57.000000
# prompt.monosyllable_count                       37.000000         37.000000
# prompt.polysyllable_count                       13.000000         13.000000
# prompt.sentence_count                            5.000000          5.000000
# prompt.sentiment_nltk                            0.112900          0.112900
# prompt.syllable_count                          105.000000        105.000000
# prompt.toxicity                                  0.020406          0.020406
# response                                              NaN               NaN
# response.aggregate_reading_level                11.000000         11.000000
# response.automated_readability_index            13.900000         13.900000
# response.character_count                       119.000000        119.000000
# response.difficult_words                         7.000000          7.000000
# response.flesch_reading_ease                    55.580000         55.580000
# response.has_patterns                                 NaN               NaN
# response.letter_count                          114.000000        114.000000
# response.lexicon_count                          24.000000         24.000000
# response.monosyllable_count                     14.000000         14.000000
# response.polysyllable_count                      3.000000          3.000000
# response.refusal_similarity                      0.186855          0.186855
# response.relevance_to_prompt                     0.768668          0.768668
# response.sentence_count                          1.000000          1.000000
# response.sentiment_nltk                          0.038700          0.038700
# response.syllable_count                         37.000000         37.000000
# response.toxicity                                0.001970          0.001970
#
#                                       distribution/n  distribution/q_01  \
# column
# prompt                                           0.0                NaN
# prompt.aggregate_reading_level                   1.0          12.000000
# prompt.automated_readability_index               1.0          12.100000
# prompt.character_count                           1.0         337.000000
# prompt.difficult_words                           1.0          13.000000
# prompt.flesch_reading_ease                       1.0          42.980000
# prompt.has_patterns                              NaN                NaN
# prompt.jailbreak_similarity                      1.0           0.276274
# prompt.letter_count                              1.0         302.000000
# prompt.lexicon_count                             1.0          57.000000
# prompt.monosyllable_count                        1.0          37.000000
# prompt.polysyllable_count                        1.0          13.000000
# prompt.sentence_count                            1.0           5.000000
# prompt.sentiment_nltk                            1.0           0.112900
# prompt.syllable_count                            1.0         105.000000
# prompt.toxicity                                  1.0           0.020406
# response                                         0.0                NaN
# response.aggregate_reading_level                 1.0          11.000000
# response.automated_readability_index             1.0          13.900000
# response.character_count                         1.0         119.000000
# response.difficult_words                         1.0           7.000000
# response.flesch_reading_ease                     1.0          55.580000
# response.has_patterns                            NaN                NaN
# response.letter_count                            1.0         114.000000
# response.lexicon_count                           1.0          24.000000
# response.monosyllable_count                      1.0          14.000000
# response.polysyllable_count                      1.0           3.000000
# response.refusal_similarity                      1.0           0.186855
# response.relevance_to_prompt                     1.0           0.768668
# response.sentence_count                          1.0           1.000000
# response.sentiment_nltk                          1.0           0.038700
# response.syllable_count                          1.0          37.000000
# response.toxicity                                1.0           0.001970
#
#                                       distribution/q_05  distribution/q_10  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            12.100000          12.100000
# prompt.character_count                       337.000000         337.000000
# prompt.difficult_words                        13.000000          13.000000
# prompt.flesch_reading_ease                    42.980000          42.980000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.276274           0.276274
# prompt.letter_count                          302.000000         302.000000
# prompt.lexicon_count                          57.000000          57.000000
# prompt.monosyllable_count                     37.000000          37.000000
# prompt.polysyllable_count                     13.000000          13.000000
# prompt.sentence_count                          5.000000           5.000000
# prompt.sentiment_nltk                          0.112900           0.112900
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.020406           0.020406
# response                                            NaN                NaN
# response.aggregate_reading_level              11.000000          11.000000
# response.automated_readability_index          13.900000          13.900000
# response.character_count                     119.000000         119.000000
# response.difficult_words                       7.000000           7.000000
# response.flesch_reading_ease                  55.580000          55.580000
# response.has_patterns                               NaN                NaN
# response.letter_count                        114.000000         114.000000
# response.lexicon_count                        24.000000          24.000000
# response.monosyllable_count                   14.000000          14.000000
# response.polysyllable_count                    3.000000           3.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.768668           0.768668
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                        0.038700           0.038700
# response.syllable_count                       37.000000          37.000000
# response.toxicity                              0.001970           0.001970
#
#                                       distribution/q_25  distribution/q_75  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            12.100000          12.100000
# prompt.character_count                       337.000000         337.000000
# prompt.difficult_words                        13.000000          13.000000
# prompt.flesch_reading_ease                    42.980000          42.980000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.276274           0.276274
# prompt.letter_count                          302.000000         302.000000
# prompt.lexicon_count                          57.000000          57.000000
# prompt.monosyllable_count                     37.000000          37.000000
# prompt.polysyllable_count                     13.000000          13.000000
# prompt.sentence_count                          5.000000           5.000000
# prompt.sentiment_nltk                          0.112900           0.112900
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.020406           0.020406
# response                                            NaN                NaN
# response.aggregate_reading_level              11.000000          11.000000
# response.automated_readability_index          13.900000          13.900000
# response.character_count                     119.000000         119.000000
# response.difficult_words                       7.000000           7.000000
# response.flesch_reading_ease                  55.580000          55.580000
# response.has_patterns                               NaN                NaN
# response.letter_count                        114.000000         114.000000
# response.lexicon_count                        24.000000          24.000000
# response.monosyllable_count                   14.000000          14.000000
# response.polysyllable_count                    3.000000           3.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.768668           0.768668
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                        0.038700           0.038700
# response.syllable_count                       37.000000          37.000000
# response.toxicity                              0.001970           0.001970
#
#                                       distribution/q_90  distribution/q_95  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            12.100000          12.100000
# prompt.character_count                       337.000000         337.000000
# prompt.difficult_words                        13.000000          13.000000
# prompt.flesch_reading_ease                    42.980000          42.980000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.276274           0.276274
# prompt.letter_count                          302.000000         302.000000
# prompt.lexicon_count                          57.000000          57.000000
# prompt.monosyllable_count                     37.000000          37.000000
# prompt.polysyllable_count                     13.000000          13.000000
# prompt.sentence_count                          5.000000           5.000000
# prompt.sentiment_nltk                          0.112900           0.112900
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.020406           0.020406
# response                                            NaN                NaN
# response.aggregate_reading_level              11.000000          11.000000
# response.automated_readability_index          13.900000          13.900000
# response.character_count                     119.000000         119.000000
# response.difficult_words                       7.000000           7.000000
# response.flesch_reading_ease                  55.580000          55.580000
# response.has_patterns                               NaN                NaN
# response.letter_count                        114.000000         114.000000
# response.lexicon_count                        24.000000          24.000000
# response.monosyllable_count                   14.000000          14.000000
# response.polysyllable_count                    3.000000           3.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.768668           0.768668
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                        0.038700           0.038700
# response.syllable_count                       37.000000          37.000000
# response.toxicity                              0.001970           0.001970
#
#                                       distribution/q_99  distribution/stddev  \
# column
# prompt                                              NaN                  0.0
# prompt.aggregate_reading_level                12.000000                  0.0
# prompt.automated_readability_index            12.100000                  0.0
# prompt.character_count                       337.000000                  0.0
# prompt.difficult_words                        13.000000                  0.0
# prompt.flesch_reading_ease                    42.980000                  0.0
# prompt.has_patterns                                 NaN                  NaN
# prompt.jailbreak_similarity                    0.276274                  0.0
# prompt.letter_count                          302.000000                  0.0
# prompt.lexicon_count                          57.000000                  0.0
# prompt.monosyllable_count                     37.000000                  0.0
# prompt.polysyllable_count                     13.000000                  0.0
# prompt.sentence_count                          5.000000                  0.0
# prompt.sentiment_nltk                          0.112900                  0.0
# prompt.syllable_count                        105.000000                  0.0
# prompt.toxicity                                0.020406                  0.0
# response                                            NaN                  0.0
# response.aggregate_reading_level              11.000000                  0.0
# response.automated_readability_index          13.900000                  0.0
# response.character_count                     119.000000                  0.0
# response.difficult_words                       7.000000                  0.0
# response.flesch_reading_ease                  55.580000                  0.0
# response.has_patterns                               NaN                  NaN
# response.letter_count                        114.000000                  0.0
# response.lexicon_count                        24.000000                  0.0
# response.monosyllable_count                   14.000000                  0.0
# response.polysyllable_count                    3.000000                  0.0
# response.refusal_similarity                    0.186855                  0.0
# response.relevance_to_prompt                   0.768668                  0.0
# response.sentence_count                        1.000000                  0.0
# response.sentiment_nltk                        0.038700                  0.0
# response.syllable_count                       37.000000                  0.0
# response.toxicity                              0.001970                  0.0
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.jailbreak_similarity           SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.sentiment_nltk                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# prompt.toxicity                       SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.refusal_similarity           SummaryType.COLUMN              0
# response.relevance_to_prompt          SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.sentiment_nltk               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
# response.toxicity                     SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                       1               0
# prompt.automated_readability_index                   1               0
# prompt.character_count                               0               1
# prompt.difficult_words                               0               1
# prompt.flesch_reading_ease                           1               0
# prompt.has_patterns                                  0               0
# prompt.jailbreak_similarity                          1               0
# prompt.letter_count                                  0               1
# prompt.lexicon_count                                 0               1
# prompt.monosyllable_count                            0               1
# prompt.polysyllable_count                            0               1
# prompt.sentence_count                                0               1
# prompt.sentiment_nltk                                1               0
# prompt.syllable_count                                0               1
# prompt.toxicity                                      1               0
# response                                             0               0
# response.aggregate_reading_level                     1               0
# response.automated_readability_index                 1               0
# response.character_count                             0               1
# response.difficult_words                             0               1
# response.flesch_reading_ease                         1               0
# response.has_patterns                                0               0
# response.letter_count                                0               1
# response.lexicon_count                               0               1
# response.monosyllable_count                          0               1
# response.polysyllable_count                          0               1
# response.refusal_similarity                          1               0
# response.relevance_to_prompt                         1               0
# response.sentence_count                              0               1
# response.sentiment_nltk                              1               0
# response.syllable_count                              0               1
# response.toxicity                                    1               0
#
#                                       types/object  types/string  \
# column
# prompt                                           0             1
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            0             0
# prompt.toxicity                                  0             0
# response                                         0             1
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             0
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.refusal_similarity                      0             0
# response.relevance_to_prompt                     0             0
# response.sentence_count                          0             0
# response.sentiment_nltk                          0             0
# response.syllable_count                          0             0
# response.toxicity                                0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0     337.0     337.0
# prompt.difficult_words                           0      13.0      13.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.jailbreak_similarity                      0       NaN       NaN
# prompt.letter_count                              0     302.0     302.0
# prompt.lexicon_count                             0      57.0      57.0
# prompt.monosyllable_count                        0      37.0      37.0
# prompt.polysyllable_count                        0      13.0      13.0
# prompt.sentence_count                            0       5.0       5.0
# prompt.sentiment_nltk                            0       NaN       NaN
# prompt.syllable_count                            0     105.0     105.0
# prompt.toxicity                                  0       NaN       NaN
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0     119.0     119.0
# response.difficult_words                         0       7.0       7.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0     114.0     114.0
# response.lexicon_count                           0      24.0      24.0
# response.monosyllable_count                      0      14.0      14.0
# response.polysyllable_count                      0       3.0       3.0
# response.refusal_similarity                      0       NaN       NaN
# response.relevance_to_prompt                     0       NaN       NaN
# response.sentence_count                          0       1.0       1.0
# response.sentiment_nltk                          0       NaN       NaN
# response.syllable_count                          0      37.0      37.0
# response.toxicity                                0       NaN       NaN
#
#                                      frequent_items/frequent_strings
# column
# prompt                                                           NaN
# prompt.aggregate_reading_level                                   NaN
# prompt.automated_readability_index                               NaN
# prompt.character_count                                           NaN
# prompt.difficult_words                                           NaN
# prompt.flesch_reading_ease                                       NaN
# prompt.has_patterns                                               []
# prompt.jailbreak_similarity                                      NaN
# prompt.letter_count                                              NaN
# prompt.lexicon_count                                             NaN
# prompt.monosyllable_count                                        NaN
# prompt.polysyllable_count                                        NaN
# prompt.sentence_count                                            NaN
# prompt.sentiment_nltk                                            NaN
# prompt.syllable_count                                            NaN
# prompt.toxicity                                                  NaN
# response                                                         NaN
# response.aggregate_reading_level                                 NaN
# response.automated_readability_index                             NaN
# response.character_count                                         NaN
# response.difficult_words                                         NaN
# response.flesch_reading_ease                                     NaN
# response.has_patterns                                             []
# response.letter_count                                            NaN
# response.lexicon_count                                           NaN
# response.monosyllable_count                                      NaN
# response.polysyllable_count                                      NaN
# response.refusal_similarity                                      NaN
# response.relevance_to_prompt                                     NaN
# response.sentence_count                                          NaN
# response.sentiment_nltk                                          NaN
# response.syllable_count                                          NaN
# response.toxicity                                                NaN

# %% [markdown]
# ## Batch Monitor LLM prompt and response

# %%
x = 10
pr_list = []
for i in range(0,x):
    question=test_dataset[i]['dialogue']
    prompt = prompt_template.format(question=question)
    prompt_and_response = predict_fn(prompt,question)
    pr_list.append(prompt_and_response)

df_pr = pd.DataFrame(pr_list)

# %%
profile = why.log(df_pr, name="sam-sum-list", schema=schema).profile()
profview = profile.view()
profview.to_pandas()
# Out:
# ✅ Aggregated 10 rows into profile sam-sum-list
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=ref-TtE8HjSUcfugdmFY
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                           10.0                 10.0
# prompt.aggregate_reading_level                    6.0                  6.0
# prompt.automated_readability_index               10.0                 10.0
# prompt.character_count                           10.0                 10.0
# prompt.difficult_words                            9.0                  9.0
# prompt.flesch_reading_ease                       10.0                 10.0
# prompt.has_patterns                               NaN                  NaN
# prompt.jailbreak_similarity                      10.0                 10.0
# prompt.letter_count                              10.0                 10.0
# prompt.lexicon_count                              9.0                  9.0
# prompt.monosyllable_count                        10.0                 10.0
# prompt.polysyllable_count                         6.0                  6.0
# prompt.sentence_count                             9.0                  9.0
# prompt.sentiment_nltk                            10.0                 10.0
# prompt.syllable_count                             8.0                  8.0
# prompt.toxicity                                  10.0                 10.0
# response                                         10.0                 10.0
# response.aggregate_reading_level                  7.0                  7.0
# response.automated_readability_index             10.0                 10.0
# response.character_count                          8.0                  8.0
# response.difficult_words                          6.0                  6.0
# response.flesch_reading_ease                     10.0                 10.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             7.0                  7.0
# response.lexicon_count                            6.0                  6.0
# response.monosyllable_count                       7.0                  7.0
# response.polysyllable_count                       5.0                  5.0
# response.refusal_similarity                      10.0                 10.0
# response.relevance_to_prompt                     10.0                 10.0
# response.sentence_count                           2.0                  2.0
# response.sentiment_nltk                          10.0                 10.0
# response.syllable_count                           7.0                  7.0
# response.toxicity                                10.0                 10.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                           10.00050           0
# prompt.aggregate_reading_level                    6.00030           0
# prompt.automated_readability_index               10.00050           0
# prompt.character_count                           10.00050           0
# prompt.difficult_words                            9.00045           0
# prompt.flesch_reading_ease                       10.00050           0
# prompt.has_patterns                                   NaN           0
# prompt.jailbreak_similarity                      10.00050           0
# prompt.letter_count                              10.00050           0
# prompt.lexicon_count                              9.00045           0
# prompt.monosyllable_count                        10.00050           0
# prompt.polysyllable_count                         6.00030           0
# prompt.sentence_count                             9.00045           0
# prompt.sentiment_nltk                            10.00050           0
# prompt.syllable_count                             8.00040           0
# prompt.toxicity                                  10.00050           0
# response                                         10.00050           0
# response.aggregate_reading_level                  7.00035           0
# response.automated_readability_index             10.00050           0
# response.character_count                          8.00040           0
# response.difficult_words                          6.00030           0
# response.flesch_reading_ease                     10.00050           0
# response.has_patterns                                 NaN           0
# response.letter_count                             7.00035           0
# response.lexicon_count                            6.00030           0
# response.monosyllable_count                       7.00035           0
# response.polysyllable_count                       5.00025           0
# response.refusal_similarity                      10.00050           0
# response.relevance_to_prompt                     10.00050           0
# response.sentence_count                           2.00010           0
# response.sentiment_nltk                          10.00050           0
# response.syllable_count                           7.00035           0
# response.toxicity                                10.00050           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                      10           0            0
# prompt.aggregate_reading_level              10           0            0
# prompt.automated_readability_index          10           0            0
# prompt.character_count                      10           0            0
# prompt.difficult_words                      10           0            0
# prompt.flesch_reading_ease                  10           0            0
# prompt.has_patterns                         10           0           10
# prompt.jailbreak_similarity                 10           0            0
# prompt.letter_count                         10           0            0
# prompt.lexicon_count                        10           0            0
# prompt.monosyllable_count                   10           0            0
# prompt.polysyllable_count                   10           0            0
# prompt.sentence_count                       10           0            0
# prompt.sentiment_nltk                       10           0            0
# prompt.syllable_count                       10           0            0
# prompt.toxicity                             10           0            0
# response                                    10           0            0
# response.aggregate_reading_level            10           0            0
# response.automated_readability_index        10           0            0
# response.character_count                    10           0            0
# response.difficult_words                    10           0            0
# response.flesch_reading_ease                10           0            0
# response.has_patterns                       10           0           10
# response.letter_count                       10           0            0
# response.lexicon_count                      10           0            0
# response.monosyllable_count                 10           0            0
# response.polysyllable_count                 10           0            0
# response.refusal_similarity                 10           0            0
# response.relevance_to_prompt                10           0            0
# response.sentence_count                     10           0            0
# response.sentiment_nltk                     10           0            0
# response.syllable_count                     10           0            0
# response.toxicity                           10           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN           0.000000
# prompt.aggregate_reading_level               12.000000           6.400000
# prompt.automated_readability_index           18.100000           8.450000
# prompt.character_count                     1250.000000         555.300000
# prompt.difficult_words                       33.000000          13.100000
# prompt.flesch_reading_ease                   88.430000          68.492000
# prompt.has_patterns                                NaN                NaN
# prompt.jailbreak_similarity                   0.293999           0.241603
# prompt.letter_count                        1185.000000         507.400000
# prompt.lexicon_count                        273.000000         113.500000
# prompt.monosyllable_count                   207.000000          83.300000
# prompt.polysyllable_count                    35.000000          15.500000
# prompt.sentence_count                        22.000000          11.000000
# prompt.sentiment_nltk                         0.989100           0.491670
# prompt.syllable_count                       394.000000         166.400000
# prompt.toxicity                               0.021360           0.008128
# response                                           NaN           0.000000
# response.aggregate_reading_level             17.000000          10.800000
# response.automated_readability_index         15.600000          11.710000
# response.character_count                    139.000000         119.900000
# response.difficult_words                      9.000000           6.000000
# response.flesch_reading_ease                 90.430000          60.704000
# response.has_patterns                              NaN                NaN
# response.letter_count                       136.000000         116.900000
# response.lexicon_count                       28.000000          25.200000
# response.monosyllable_count                  20.000000          16.300000
# response.polysyllable_count                   4.000000           2.500000
# response.refusal_similarity                   0.186855           0.096092
# response.relevance_to_prompt                  0.780735           0.685603
# response.sentence_count                       2.000000           1.300000
# response.sentiment_nltk                       0.784500           0.037930
# response.syllable_count                      42.000000          37.300000
# response.toxicity                             0.006023           0.001756
#
#                                       distribution/median  distribution/min  \
# column
# prompt                                                NaN               NaN
# prompt.aggregate_reading_level                   8.000000          0.000000
# prompt.automated_readability_index               7.600000          3.600000
# prompt.character_count                         383.000000        329.000000
# prompt.difficult_words                          13.000000          5.000000
# prompt.flesch_reading_ease                      66.840000         42.980000
# prompt.has_patterns                                   NaN               NaN
# prompt.jailbreak_similarity                      0.276274          0.166880
# prompt.letter_count                            350.000000        302.000000
# prompt.lexicon_count                            79.000000         57.000000
# prompt.monosyllable_count                       61.000000         37.000000
# prompt.polysyllable_count                       13.000000          8.000000
# prompt.sentence_count                           11.000000          2.000000
# prompt.sentiment_nltk                            0.942400         -0.926000
# prompt.syllable_count                          112.000000        105.000000
# prompt.toxicity                                  0.004268          0.001150
# response                                              NaN               NaN
# response.aggregate_reading_level                11.000000          5.000000
# response.automated_readability_index            13.100000          6.800000
# response.character_count                       119.000000         89.000000
# response.difficult_words                         7.000000          1.000000
# response.flesch_reading_ease                    55.580000         42.380000
# response.has_patterns                                 NaN               NaN
# response.letter_count                          118.000000         86.000000
# response.lexicon_count                          26.000000         23.000000
# response.monosyllable_count                     17.000000         12.000000
# response.polysyllable_count                      3.000000          0.000000
# response.refusal_similarity                      0.082078          0.062397
# response.relevance_to_prompt                     0.708772          0.559312
# response.sentence_count                          1.000000          1.000000
# response.sentiment_nltk                          0.038700         -0.781800
# response.syllable_count                         40.000000         25.000000
# response.toxicity                                0.001211          0.000850
#
#                                       distribution/n  distribution/q_01  \
# column
# prompt                                           0.0                NaN
# prompt.aggregate_reading_level                  10.0           0.000000
# prompt.automated_readability_index              10.0           3.600000
# prompt.character_count                          10.0         329.000000
# prompt.difficult_words                          10.0           5.000000
# prompt.flesch_reading_ease                      10.0          42.980000
# prompt.has_patterns                              NaN                NaN
# prompt.jailbreak_similarity                     10.0           0.166880
# prompt.letter_count                             10.0         302.000000
# prompt.lexicon_count                            10.0          57.000000
# prompt.monosyllable_count                       10.0          37.000000
# prompt.polysyllable_count                       10.0           8.000000
# prompt.sentence_count                           10.0           2.000000
# prompt.sentiment_nltk                           10.0          -0.926000
# prompt.syllable_count                           10.0         105.000000
# prompt.toxicity                                 10.0           0.001150
# response                                         0.0                NaN
# response.aggregate_reading_level                10.0           5.000000
# response.automated_readability_index            10.0           6.800000
# response.character_count                        10.0          89.000000
# response.difficult_words                        10.0           1.000000
# response.flesch_reading_ease                    10.0          42.380000
# response.has_patterns                            NaN                NaN
# response.letter_count                           10.0          86.000000
# response.lexicon_count                          10.0          23.000000
# response.monosyllable_count                     10.0          12.000000
# response.polysyllable_count                     10.0           0.000000
# response.refusal_similarity                     10.0           0.062397
# response.relevance_to_prompt                    10.0           0.559312
# response.sentence_count                         10.0           1.000000
# response.sentiment_nltk                         10.0          -0.781800
# response.syllable_count                         10.0          25.000000
# response.toxicity                               10.0           0.000850
#
#                                       distribution/q_05  distribution/q_10  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 0.000000           4.000000
# prompt.automated_readability_index             3.600000           4.500000
# prompt.character_count                       329.000000         337.000000
# prompt.difficult_words                         5.000000           5.000000
# prompt.flesch_reading_ease                    42.980000          51.350000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.166880           0.183089
# prompt.letter_count                          302.000000         310.000000
# prompt.lexicon_count                          57.000000          66.000000
# prompt.monosyllable_count                     37.000000          44.000000
# prompt.polysyllable_count                      8.000000           8.000000
# prompt.sentence_count                          2.000000           5.000000
# prompt.sentiment_nltk                         -0.926000          -0.749400
# prompt.syllable_count                        105.000000         105.000000
# prompt.toxicity                                0.001150           0.001226
# response                                            NaN                NaN
# response.aggregate_reading_level               5.000000           7.000000
# response.automated_readability_index           6.800000           6.900000
# response.character_count                      89.000000         115.000000
# response.difficult_words                       1.000000           3.000000
# response.flesch_reading_ease                  42.380000          45.090000
# response.has_patterns                               NaN                NaN
# response.letter_count                         86.000000         112.000000
# response.lexicon_count                        23.000000          23.000000
# response.monosyllable_count                   12.000000          14.000000
# response.polysyllable_count                    0.000000           1.000000
# response.refusal_similarity                    0.062397           0.068889
# response.relevance_to_prompt                   0.559312           0.602750
# response.sentence_count                        1.000000           1.000000
# response.sentiment_nltk                       -0.781800          -0.680800
# response.syllable_count                       25.000000          34.000000
# response.toxicity                              0.000850           0.000902
#
#                                       distribution/q_25  distribution/q_75  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 5.000000           8.000000
# prompt.automated_readability_index             4.900000          11.500000
# prompt.character_count                       347.000000         842.000000
# prompt.difficult_words                         6.000000          15.000000
# prompt.flesch_reading_ease                    63.460000          79.560000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.195369           0.285500
# prompt.letter_count                          317.000000         747.000000
# prompt.lexicon_count                          73.000000         158.000000
# prompt.monosyllable_count                     54.000000         107.000000
# prompt.polysyllable_count                      9.000000          17.000000
# prompt.sentence_count                          7.000000          13.000000
# prompt.sentiment_nltk                          0.112900           0.971300
# prompt.syllable_count                        105.000000         240.000000
# prompt.toxicity                                0.002444           0.013864
# response                                            NaN                NaN
# response.aggregate_reading_level               7.000000          13.000000
# response.automated_readability_index           8.300000          14.000000
# response.character_count                     117.000000         127.000000
# response.difficult_words                       6.000000           7.000000
# response.flesch_reading_ease                  51.520000          75.710000
# response.has_patterns                               NaN                NaN
# response.letter_count                        113.000000         123.000000
# response.lexicon_count                        24.000000          26.000000
# response.monosyllable_count                   15.000000          17.000000
# response.polysyllable_count                    1.000000           4.000000
# response.refusal_similarity                    0.077743           0.105742
# response.relevance_to_prompt                   0.618423           0.754272
# response.sentence_count                        1.000000           2.000000
# response.sentiment_nltk                       -0.395000           0.571900
# response.syllable_count                       35.000000          42.000000
# response.toxicity                              0.000905           0.001778
#
#                                       distribution/q_90  distribution/q_95  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                12.000000          12.000000
# prompt.automated_readability_index            18.100000          18.100000
# prompt.character_count                      1250.000000        1250.000000
# prompt.difficult_words                        33.000000          33.000000
# prompt.flesch_reading_ease                    88.430000          88.430000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.293999           0.293999
# prompt.letter_count                         1185.000000        1185.000000
# prompt.lexicon_count                         273.000000         273.000000
# prompt.monosyllable_count                    207.000000         207.000000
# prompt.polysyllable_count                     35.000000          35.000000
# prompt.sentence_count                         22.000000          22.000000
# prompt.sentiment_nltk                          0.989100           0.989100
# prompt.syllable_count                        394.000000         394.000000
# prompt.toxicity                                0.021360           0.021360
# response                                            NaN                NaN
# response.aggregate_reading_level              17.000000          17.000000
# response.automated_readability_index          15.600000          15.600000
# response.character_count                     139.000000         139.000000
# response.difficult_words                       9.000000           9.000000
# response.flesch_reading_ease                  90.430000          90.430000
# response.has_patterns                               NaN                NaN
# response.letter_count                        136.000000         136.000000
# response.lexicon_count                        28.000000          28.000000
# response.monosyllable_count                   20.000000          20.000000
# response.polysyllable_count                    4.000000           4.000000
# response.refusal_similarity                    0.186855           0.186855
# response.relevance_to_prompt                   0.780735           0.780735
# response.sentence_count                        2.000000           2.000000
# response.sentiment_nltk                        0.784500           0.784500
# response.syllable_count                       42.000000          42.000000
# response.toxicity                              0.006023           0.006023
#
#                                       distribution/q_99  distribution/stddev  \
# column
# prompt                                              NaN             0.000000
# prompt.aggregate_reading_level                12.000000             3.204164
# prompt.automated_readability_index            18.100000             4.481629
# prompt.character_count                      1250.000000           319.057309
# prompt.difficult_words                        33.000000             8.184674
# prompt.flesch_reading_ease                    88.430000            14.224877
# prompt.has_patterns                                 NaN                  NaN
# prompt.jailbreak_similarity                    0.293999             0.049072
# prompt.letter_count                         1185.000000           299.966368
# prompt.lexicon_count                         273.000000            69.437822
# prompt.monosyllable_count                    207.000000            53.425025
# prompt.polysyllable_count                     35.000000             9.478045
# prompt.sentence_count                         22.000000             6.218253
# prompt.sentiment_nltk                          0.989100             0.750595
# prompt.syllable_count                        394.000000            97.653810
# prompt.toxicity                                0.021360             0.007873
# response                                            NaN             0.000000
# response.aggregate_reading_level              17.000000             3.852849
# response.automated_readability_index          15.600000             3.240182
# response.character_count                     139.000000            13.763478
# response.difficult_words                       9.000000             2.357023
# response.flesch_reading_ease                  90.430000            16.535750
# response.has_patterns                               NaN                  NaN
# response.letter_count                        136.000000            14.090580
# response.lexicon_count                        28.000000             1.686548
# response.monosyllable_count                   20.000000             2.213594
# response.polysyllable_count                    4.000000             1.433721
# response.refusal_similarity                    0.186855             0.036516
# response.relevance_to_prompt                   0.780735             0.077414
# response.sentence_count                        2.000000             0.483046
# response.sentiment_nltk                        0.784500             0.580320
# response.syllable_count                       42.000000             5.375872
# response.toxicity                              0.006023             0.001552
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.jailbreak_similarity           SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.sentiment_nltk                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# prompt.toxicity                       SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.refusal_similarity           SummaryType.COLUMN              0
# response.relevance_to_prompt          SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.sentiment_nltk               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
# response.toxicity                     SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                      10               0
# prompt.automated_readability_index                  10               0
# prompt.character_count                               0              10
# prompt.difficult_words                               0              10
# prompt.flesch_reading_ease                          10               0
# prompt.has_patterns                                  0               0
# prompt.jailbreak_similarity                         10               0
# prompt.letter_count                                  0              10
# prompt.lexicon_count                                 0              10
# prompt.monosyllable_count                            0              10
# prompt.polysyllable_count                            0              10
# prompt.sentence_count                                0              10
# prompt.sentiment_nltk                               10               0
# prompt.syllable_count                                0              10
# prompt.toxicity                                     10               0
# response                                             0               0
# response.aggregate_reading_level                    10               0
# response.automated_readability_index                10               0
# response.character_count                             0              10
# response.difficult_words                             0              10
# response.flesch_reading_ease                        10               0
# response.has_patterns                                0               0
# response.letter_count                                0              10
# response.lexicon_count                               0              10
# response.monosyllable_count                          0              10
# response.polysyllable_count                          0              10
# response.refusal_similarity                         10               0
# response.relevance_to_prompt                        10               0
# response.sentence_count                              0              10
# response.sentiment_nltk                             10               0
# response.syllable_count                              0              10
# response.toxicity                                   10               0
#
#                                       types/object  types/string  \
# column
# prompt                                           0            10
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            0             0
# prompt.toxicity                                  0             0
# response                                         0            10
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             0
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.refusal_similarity                      0             0
# response.relevance_to_prompt                     0             0
# response.sentence_count                          0             0
# response.sentiment_nltk                          0             0
# response.syllable_count                          0             0
# response.toxicity                                0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0    1250.0     329.0
# prompt.difficult_words                           0      33.0       5.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.jailbreak_similarity                      0       NaN       NaN
# prompt.letter_count                              0    1185.0     302.0
# prompt.lexicon_count                             0     273.0      57.0
# prompt.monosyllable_count                        0     207.0      37.0
# prompt.polysyllable_count                        0      35.0       8.0
# prompt.sentence_count                            0      22.0       2.0
# prompt.sentiment_nltk                            0       NaN       NaN
# prompt.syllable_count                            0     394.0     105.0
# prompt.toxicity                                  0       NaN       NaN
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0     139.0      89.0
# response.difficult_words                         0       9.0       1.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0     136.0      86.0
# response.lexicon_count                           0      28.0      23.0
# response.monosyllable_count                      0      20.0      12.0
# response.polysyllable_count                      0       4.0       0.0
# response.refusal_similarity                      0       NaN       NaN
# response.relevance_to_prompt                     0       NaN       NaN
# response.sentence_count                          0       2.0       1.0
# response.sentiment_nltk                          0       NaN       NaN
# response.syllable_count                          0      42.0      25.0
# response.toxicity                                0       NaN       NaN
#
#                                      frequent_items/frequent_strings
# column
# prompt                                                           NaN
# prompt.aggregate_reading_level                                   NaN
# prompt.automated_readability_index                               NaN
# prompt.character_count                                           NaN
# prompt.difficult_words                                           NaN
# prompt.flesch_reading_ease                                       NaN
# prompt.has_patterns                                               []
# prompt.jailbreak_similarity                                      NaN
# prompt.letter_count                                              NaN
# prompt.lexicon_count                                             NaN
# prompt.monosyllable_count                                        NaN
# prompt.polysyllable_count                                        NaN
# prompt.sentence_count                                            NaN
# prompt.sentiment_nltk                                            NaN
# prompt.syllable_count                                            NaN
# prompt.toxicity                                                  NaN
# response                                                         NaN
# response.aggregate_reading_level                                 NaN
# response.automated_readability_index                             NaN
# response.character_count                                         NaN
# response.difficult_words                                         NaN
# response.flesch_reading_ease                                     NaN
# response.has_patterns                                             []
# response.letter_count                                            NaN
# response.lexicon_count                                           NaN
# response.monosyllable_count                                      NaN
# response.polysyllable_count                                      NaN
# response.refusal_similarity                                      NaN
# response.relevance_to_prompt                                     NaN
# response.sentence_count                                          NaN
# response.sentiment_nltk                                          NaN
# response.syllable_count                                          NaN
# response.toxicity                                                NaN

# %% [markdown]
# ### Back Filling with WhyLabs
#
# Write seven day prompt list

# %%
prompt_lists = [
    ["How can I create a new account?", "Great job to the team", "Fantastic product, had a good experience"],
    ["This product made me angry, can I return it? Give a phone number to call 800-987-6543", "You dumb and smell bad", "I hated the experience, and I was over charged"],
    ["This seems amazing, could you share the pricing?", "Incredible site, could we setup a call?", "Hello! Can you kindly guide me through the documentation?"],
    ["This looks impressive, could you provide some information on the cost?", "Stunning platform, can we arrange a chat?", "Hello there! Could you assist me with the documentation?"],
    ["This looks remarkable, could you tell me the price range?", "Fantastic webpage, is it possible to organize a call?", "Greetings! Can you help me with the relevant documents?"],
    ["This is great, Ilove it, could you inform me about the charges?", "love the interface, can we have a teleconference?", "Hello! Can I take a look at the user manuals?"],
    ["This seems fantastic, how much does it cost?", "Excellent website, can we setup a call?", "Hello! Could you help me find the resource documents?"]
]

# %%
import datetime
telemetry_agent = WhyLabsWriter()
all_prompts_and_responses = []  # This list will store all the prompts and responses.


for i, day in enumerate(prompt_lists):
  # walking backwards. Each dataset has to map to a date to show up as a different batch in WhyLabs
  dt = datetime.datetime.now(tz=datetime.timezone.utc) - datetime.timedelta(days=i)
  for question in day:
    prompt = prompt_template.format(question=question)
    prompt_and_response = predict_fn(prompt,question)
    profile = why.log(prompt_and_response, schema=schema)

     # Save the prompt and its response in the list.
    all_prompts_and_responses.append(prompt_and_response)

    # set the dataset timestamp for the profile
    profile.set_dataset_timestamp(dt)
    telemetry_agent.write(profile.view())
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000

# %%
all_prompts_and_responses
# Out:
# [{'prompt': 'How can I create a new account?',
#   'response': 'To create a new account, you will need to provide the required information and follow the registration process. The specific steps may vary depending on the platform or'},
#  {'prompt': 'Great job to the team',
#   'response': 'The team received praise for their work. A positive acknowledgement was given to them.'},
#  {'prompt': 'Fantastic product, had a good experience',
#   'response': 'The customer had a positive experience with the product, describing it as fantastic. They expressed satisfaction with their interaction.'},
#  {'prompt': 'This product made me angry, can I return it? Give a phone number to call 800-987-6543',
#   'response': 'The customer is unhappy with a product and wants to return it, and they are asking for a phone number to call to initiate the return process. The'},
#  {'prompt': 'You dumb and smell bad',
#   'response': "You made a personal insult and a comment about someone's hygiene."},
#  {'prompt': 'I hated the experience, and I was over charged',
#   'response': 'The person had a negative experience and felt overcharged.'},
#  {'prompt': 'This seems amazing, could you share the pricing?',
#   'response': 'The user expressed interest in the product and requested information about the pricing.'},
#  {'prompt': 'Incredible site, could we setup a call?',
#   'response': 'The user complimented a website and requested to set up a call.'},
#  {'prompt': 'Hello! Can you kindly guide me through the documentation?',
#   'response': 'There is no conversation to summarize.'},
#  {'prompt': 'This looks impressive, could you provide some information on the cost?',
#   'response': 'The conversation is about inquiring about the cost of something that has been presented as impressive. The person asking is seeking information on the cost of the impressive'},
#  {'prompt': 'Stunning platform, can we arrange a chat?',
#   'response': 'A user initiated a conversation by complimenting a platform and expressing a desire to chat.'},
#  {'prompt': 'Hello there! Could you assist me with the documentation?',
#   'response': 'You asked for assistance with documentation.'},
#  {'prompt': 'This looks remarkable, could you tell me the price range?',
#   'response': 'You asked about the price range of something that looks remarkable.'},
#  {'prompt': 'Fantastic webpage, is it possible to organize a call?',
#   'response': "The conversation is about a webpage and the user is asking if it's possible to organize a call."},
#  {'prompt': 'Greetings! Can you help me with the relevant documents?',
#   'response': 'You need help with relevant documents, but no conversation has been provided to summarize.'},
#  {'prompt': 'This is great, Ilove it, could you inform me about the charges?',
#   'response': 'You expressed enthusiasm for something and asked about the charges associated with it.'},
#  {'prompt': 'love the interface, can we have a teleconference?',
#   'response': 'You like the interface and would like to have a teleconference.'},
#  {'prompt': 'Hello! Can I take a look at the user manuals?',
#   'response': 'You asked to see the user manuals.'},
#  {'prompt': 'This seems fantastic, how much does it cost?',
#   'response': 'The conversation is about inquiring about the cost of something that is described as "fantastic". The cost is not specified.'},
#  {'prompt': 'Excellent website, can we setup a call?',
#   'response': 'You complimented a website and expressed interest in setting up a call.'},
#  {'prompt': 'Hello! Could you help me find the resource documents?',
#   'response': 'You asked for help finding resource documents.'}]

# %%
test_dataset_subset = test_dataset['dialogue'][0:10]

# %%
import datetime
telemetry_agent = WhyLabsWriter()
all_prompts_and_responses = []  # This list will store all the prompts and responses.

for i, question in enumerate(test_dataset_subset):
  # walking backwards. Each dataset has to map to a date to show up as a different batch in WhyLabs
  dt = datetime.datetime.now(tz=datetime.timezone.utc) - datetime.timedelta(days=i)
  
  prompt = prompt_template.format(question=question)
  prompt_and_response = predict_fn(prompt,question)
  profile = why.log(prompt_and_response, schema=schema)

 # Save the prompt and its response in the list.
  all_prompts_and_responses.append(prompt_and_response)

# set the dataset timestamp for the profile
  profile.set_dataset_timestamp(dt)  
  telemetry_agent.write(profile.view())
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-2/profiles?profile=1726531200000

# %% [markdown]
# ![](./1b_summary.png)

# %% [markdown]
# ![](./1c_profile.png)

# %% [markdown]
# ![](./1d_insights.png)

# %% [markdown]
# ![](./2_security.png)

# %% [markdown]
# ![](./3_performance.png)

# %% [markdown]
# ![](./4_performance.png)

# %% [markdown]
# ![](./5_performance.png)
